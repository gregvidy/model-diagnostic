# %%
import pickle
import pandas as pd
import numpy as np
import gc

# %% [markdown]
# ## RF

# %%
filepath_base_rf = "model/credit/base_rf_ros_38_feats_20250702.pkl"
with open(filepath_base_rf, "rb") as f:
    base_rf = pickle.load(f)

# %% [markdown]
# ## Data

# %%
df_final = pd.read_parquet("data/ready_to_train/df_credit_final_21_feats_20250702.parquet")

# %%
# setup pipeline
from src.model_pipeline import ModelPipeline

pipeline_rf = ModelPipeline(model_type="random_forest", random_state=42)

split_date = '2025-05-01'
df_splits = pipeline_rf.split_data_by_date(
    df=df_final,
    date_column="Transaction Datetime",
    split_date=split_date
)
# Out:
# Initializing ModelPipeline with model type: random_forest
# Retrieving model instance for type: random_forest
# Splitting data by date (pre-preprocessing)...
# Train samples: 1197282, Test samples: 201546
# Data splitting complete.

# %%
# prepare OOS data
target_col = "Confirmed"
X, y = pipeline_rf.prepare_data(
    df=df_splits["df_train"],
    target_column=target_col,
    exclude_columns=["Transaction Datetime"],
    is_apply_one_hot=True,
    is_apply_log=False,
    is_impute_median=False,
    is_training=True
)
# Out:
# Preparing data (is_training=True)...
# Starting core numeric and boolean preprocessing...
# Core numeric and boolean preprocessing complete.
# Fitting CategoryManager...
#   Fitted categories for column 'CustomerSex': ['0', '1', '2', '__missing__']
#   Fitted categories for column 'MCCCategory': ['AIRLINES, AIR CARRIERS', 'ASSOCIATIONS/ORGANIZATIONS', 'BUSINESS/PROFESSIONAL/MISCELLANEOUS SERVICES', 'CAR RENTAL AGENCIES', 'CLOTHING/SHOES/ACCESSORIES/UNIFORMS/RETAIL STORES/BUYING AND SELLING SERVICES', 'EDUCATIONAL SERVICES', 'ELECTRONIC AND TECHNICAL SERVICES', 'ENTERTAINMENT/THEATER/DANCE STUDIOS', 'FINANCIAL SERVICES', 'FURNISHINGS/APPLIANCES/MAINTENANCE/HOME', 'GROCERY STORES/PHARMACIES/FOOD SERVICES/RESTAURANTS', 'HEALTHCARE/CHILD SERVICES', 'LODGING — HOTELS, MOTELS, RESORTS', 'OTHER', 'PERSONAL SERVICES', 'TRAVEL/TRANSPORTATION/GAS AND FUEL SERVICES', '__missing__']
# CategoryManager fitting complete.
# Transforming data using CategoryManager...
# CategoryManager transformation complete.
# Applying One-Hot Encoders for column: Index(['CustomerSex', 'MCCCategory'], dtype='object')...
# Identified numerical columns for imputation: ['AvgTimeFirstTxnToCurrentMCCL30D', 'TxnCountToPOSModeL15min', 'RatioTxnCountToPOSModeL30DL15min', 'CntUniqueCardNoByCurrencyCodeL30D', 'RatioTxnCountL30DL15min', 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min', 'TransactionAmount', 'CntUniqueMCCByCardNoL15min', 'TxnTimeDifference', 'RatioCntUniqueMCCByCardNoL30DL15min', 'TxnCountL15min', 'RatioTxnCountToCountryCodeL30DL15min', 'RatioTxnCountToMCCL30DL15min', 'RatioSumAmtToMCCL30DL15min', 'TxnCountToCountryCodeL15min', 'MaxAmtToMCCL30D', 'AvgTimeFirstTxnToCurrentMCCL15min', 'TotalTrxAmount10Mi', 'IsTop10HighRiskMCCLast30D']
# Identified categorical columns (encoded): []
# Fitting NumericalImputer...
# NumericalImputer fitting complete.
# Transforming data using NumericalImputer...
#   Imputed column 'AvgTimeFirstTxnToCurrentMCCL30D' with value: 0
#   Imputed column 'TxnCountToPOSModeL15min' with value: 0
#   Imputed column 'RatioTxnCountToPOSModeL30DL15min' with value: 0
#   Imputed column 'CntUniqueCardNoByCurrencyCodeL30D' with value: 0
#   Imputed column 'RatioTxnCountL30DL15min' with value: 0
#   Imputed column 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min' with value: 0
#   Imputed column 'TransactionAmount' with value: 0
#   Imputed column 'CntUniqueMCCByCardNoL15min' with value: 0
#   Imputed column 'TxnTimeDifference' with value: 0
#   Imputed column 'RatioCntUniqueMCCByCardNoL30DL15min' with value: 0
#   Imputed column 'TxnCountL15min' with value: 0
#   Imputed column 'RatioTxnCountToCountryCodeL30DL15min' with value: 0
#   Imputed column 'RatioTxnCountToMCCL30DL15min' with value: 0
#   Imputed column 'RatioSumAmtToMCCL30DL15min' with value: 0
#   Imputed column 'TxnCountToCountryCodeL15min' with value: 0
#   Imputed column 'MaxAmtToMCCL30D' with value: 0
#   Imputed column 'AvgTimeFirstTxnToCurrentMCCL15min' with value: 0
#   Imputed column 'TotalTrxAmount10Mi' with value: 0
#   Imputed column 'IsTop10HighRiskMCCLast30D' with value: 0
# NumericalImputer transformation complete.
# Final feature columns: ['AvgTimeFirstTxnToCurrentMCCL30D', 'TxnCountToPOSModeL15min', 'RatioTxnCountToPOSModeL30DL15min', 'CntUniqueCardNoByCurrencyCodeL30D', 'RatioTxnCountL30DL15min', 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min', 'TransactionAmount', 'CntUniqueMCCByCardNoL15min', 'TxnTimeDifference', 'RatioCntUniqueMCCByCardNoL30DL15min', 'TxnCountL15min', 'RatioTxnCountToCountryCodeL30DL15min', 'RatioTxnCountToMCCL30DL15min', 'RatioSumAmtToMCCL30DL15min', 'TxnCountToCountryCodeL15min', 'MaxAmtToMCCL30D', 'AvgTimeFirstTxnToCurrentMCCL15min', 'TotalTrxAmount10Mi', 'IsTop10HighRiskMCCLast30D', 'CustomerSex_1', 'CustomerSex_2', 'CustomerSex___missing__', 'MCCCategory_ASSOCIATIONS/ORGANIZATIONS', 'MCCCategory_BUSINESS/PROFESSIONAL/MISCELLANEOUS SERVICES', 'MCCCategory_CAR RENTAL AGENCIES', 'MCCCategory_CLOTHING/SHOES/ACCESSORIES/UNIFORMS/RETAIL STORES/BUYING AND SELLING SERVICES', 'MCCCategory_EDUCATIONAL SERVICES', 'MCCCategory_ELECTRONIC AND TECHNICAL SERVICES', 'MCCCategory_ENTERTAINMENT/THEATER/DANCE STUDIOS', 'MCCCategory_FINANCIAL SERVICES', 'MCCCategory_FURNISHINGS/APPLIANCES/MAINTENANCE/HOME', 'MCCCategory_GROCERY STORES/PHARMACIES/FOOD SERVICES/RESTAURANTS', 'MCCCategory_HEALTHCARE/CHILD SERVICES', 'MCCCategory_LODGING — HOTELS, MOTELS, RESORTS', 'MCCCategory_OTHER', 'MCCCategory_PERSONAL SERVICES', 'MCCCategory_TRAVEL/TRANSPORTATION/GAS AND FUEL SERVICES', 'MCCCategory___missing__']
# Data preparation complete.

# %%
X_oos, y_oos = pipeline_rf.prepare_data(
    df=df_splits["df_test"],
    target_column=target_col,
    exclude_columns=["Transaction Datetime"],
    is_apply_one_hot=True,
    is_apply_log=False,
    is_impute_median=False,
    is_training=False
)
# Out:
# Preparing data (is_training=False)...
# Starting core numeric and boolean preprocessing...
# Core numeric and boolean preprocessing complete.
# Transforming data using CategoryManager...
# CategoryManager transformation complete.
# Applying One-Hot Encoders for column: Index(['CustomerSex', 'MCCCategory'], dtype='object')...
# Identified numerical columns for imputation: ['AvgTimeFirstTxnToCurrentMCCL30D', 'TxnCountToPOSModeL15min', 'RatioTxnCountToPOSModeL30DL15min', 'CntUniqueCardNoByCurrencyCodeL30D', 'RatioTxnCountL30DL15min', 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min', 'TransactionAmount', 'CntUniqueMCCByCardNoL15min', 'TxnTimeDifference', 'RatioCntUniqueMCCByCardNoL30DL15min', 'TxnCountL15min', 'RatioTxnCountToCountryCodeL30DL15min', 'RatioTxnCountToMCCL30DL15min', 'RatioSumAmtToMCCL30DL15min', 'TxnCountToCountryCodeL15min', 'MaxAmtToMCCL30D', 'AvgTimeFirstTxnToCurrentMCCL15min', 'TotalTrxAmount10Mi', 'IsTop10HighRiskMCCLast30D']
# Identified categorical columns (encoded): []
# Transforming data using NumericalImputer...
#   Imputed column 'AvgTimeFirstTxnToCurrentMCCL30D' with value: 0
#   Imputed column 'TxnCountToPOSModeL15min' with value: 0
#   Imputed column 'RatioTxnCountToPOSModeL30DL15min' with value: 0
#   Imputed column 'CntUniqueCardNoByCurrencyCodeL30D' with value: 0
#   Imputed column 'RatioTxnCountL30DL15min' with value: 0
#   Imputed column 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min' with value: 0
#   Imputed column 'TransactionAmount' with value: 0
#   Imputed column 'CntUniqueMCCByCardNoL15min' with value: 0
#   Imputed column 'TxnTimeDifference' with value: 0
#   Imputed column 'RatioCntUniqueMCCByCardNoL30DL15min' with value: 0
#   Imputed column 'TxnCountL15min' with value: 0
#   Imputed column 'RatioTxnCountToCountryCodeL30DL15min' with value: 0
#   Imputed column 'RatioTxnCountToMCCL30DL15min' with value: 0
#   Imputed column 'RatioSumAmtToMCCL30DL15min' with value: 0
#   Imputed column 'TxnCountToCountryCodeL15min' with value: 0
#   Imputed column 'MaxAmtToMCCL30D' with value: 0
#   Imputed column 'AvgTimeFirstTxnToCurrentMCCL15min' with value: 0
#   Imputed column 'TotalTrxAmount10Mi' with value: 0
#   Imputed column 'IsTop10HighRiskMCCLast30D' with value: 0
# NumericalImputer transformation complete.
# Final feature columns: ['AvgTimeFirstTxnToCurrentMCCL30D', 'TxnCountToPOSModeL15min', 'RatioTxnCountToPOSModeL30DL15min', 'CntUniqueCardNoByCurrencyCodeL30D', 'RatioTxnCountL30DL15min', 'RatioCntUniqueCardNoByCurrencyCodeL30DL15min', 'TransactionAmount', 'CntUniqueMCCByCardNoL15min', 'TxnTimeDifference', 'RatioCntUniqueMCCByCardNoL30DL15min', 'TxnCountL15min', 'RatioTxnCountToCountryCodeL30DL15min', 'RatioTxnCountToMCCL30DL15min', 'RatioSumAmtToMCCL30DL15min', 'TxnCountToCountryCodeL15min', 'MaxAmtToMCCL30D', 'AvgTimeFirstTxnToCurrentMCCL15min', 'TotalTrxAmount10Mi', 'IsTop10HighRiskMCCLast30D', 'CustomerSex_1', 'CustomerSex_2', 'CustomerSex___missing__', 'MCCCategory_ASSOCIATIONS/ORGANIZATIONS', 'MCCCategory_BUSINESS/PROFESSIONAL/MISCELLANEOUS SERVICES', 'MCCCategory_CAR RENTAL AGENCIES', 'MCCCategory_CLOTHING/SHOES/ACCESSORIES/UNIFORMS/RETAIL STORES/BUYING AND SELLING SERVICES', 'MCCCategory_EDUCATIONAL SERVICES', 'MCCCategory_ELECTRONIC AND TECHNICAL SERVICES', 'MCCCategory_ENTERTAINMENT/THEATER/DANCE STUDIOS', 'MCCCategory_FINANCIAL SERVICES', 'MCCCategory_FURNISHINGS/APPLIANCES/MAINTENANCE/HOME', 'MCCCategory_GROCERY STORES/PHARMACIES/FOOD SERVICES/RESTAURANTS', 'MCCCategory_HEALTHCARE/CHILD SERVICES', 'MCCCategory_LODGING — HOTELS, MOTELS, RESORTS', 'MCCCategory_OTHER', 'MCCCategory_PERSONAL SERVICES', 'MCCCategory_TRAVEL/TRANSPORTATION/GAS AND FUEL SERVICES', 'MCCCategory___missing__']
# Data preparation complete.

# %% [markdown]
# # Binning Proba Analysis

# %%
from src.utils import plot_confusion_matrix, generate_pred_df, compute_bin_aggregates

# %%
df_pred = generate_pred_df(
    X=X_oos,
    y=y_oos,
    clf=base_rf,
    amount_col='TransactionAmount',
    bin_on='pbad',
    increment_bin_rate=0.025,
    bins=None
)

# %%
df_agg = compute_bin_aggregates(df_pred)
# Out:
# C:\Users\Administrator\BDI-predator\ml-fraud\src\utils.py:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   aggregated_df = pred_df.groupby("bin").agg(agg_cols)

# %%
df_agg.to_csv("data/result/credit_rf_bin_proba_analysis_20250702.csv")

# %%
df_agg[["total_trnx_amt", "cum_bad_rate", "cum_good_rate", "cum_records_passed", "cum_records_rejected", "pass_through_rate"]]
# Out:
#                total_trnx_amt  cum_bad_rate  cum_good_rate  \
# bin
# [0.0, 0.025)     2.024242e+11      0.007403       0.992597
# [0.025, 0.05)    5.792455e+10      0.026661       0.973339
# [0.05, 0.075)    1.778302e+10      0.047128       0.952872
# [0.075, 0.1)     1.421309e+10      0.061404       0.938596
# [0.1, 0.125)     1.110225e+10      0.075184       0.924816
# [0.125, 0.15)    7.789358e+09      0.087222       0.912778
# [0.15, 0.175)    7.664394e+09      0.099520       0.900480
# [0.175, 0.2)     4.977359e+09      0.113902       0.886098
# [0.2, 0.225)     3.514862e+09      0.127309       0.872691
# [0.225, 0.25)    3.754291e+09      0.142422       0.857578
# [0.25, 0.275)    2.142504e+09      0.158547       0.841453
# [0.275, 0.3)     1.694271e+09      0.171575       0.828425
# [0.3, 0.325)     1.057120e+09      0.186663       0.813337
# [0.325, 0.35)    1.060238e+09      0.200616       0.799384
# [0.35, 0.375)    1.392390e+09      0.214948       0.785052
# [0.375, 0.4)     4.908564e+08      0.227009       0.772991
# [0.4, 0.425)     4.530191e+08      0.239465       0.760535
# [0.425, 0.45)    4.317719e+08      0.248894       0.751106
# [0.975, 1.0)                  259                201546           0.001285

# %%
y_oos_prob = base_rf.predict_proba(X_oos)[:, 1]

# %%
df_pred = X_oos.join(y_oos)
df_pred = df_pred[['Confirmed']]

# %%
df_pred['P_Bad'] = y_oos_prob
df_pred['Confirmed'] = df_pred['Confirmed'].astype(int)

# %%
df_pred.to_csv("data/result/CREDIT_df_pred_oos_rf_20250703.csv")

# %% [markdown]
# # Feature Importance

# %%
df_importance = pd.DataFrame(
    {"feature": X.columns, "importance": base_rf.feature_importances_}
).sort_values(by="importance", ascending=False).reset_index(drop=True)

# %%
df_importance.to_csv("data/result/credit_rf_importance_20250624.csv", index=False)

# %% [markdown]
# # False Positive Reduction

# %%
from src.utils import plot_confusion_matrix

# %%
y_oos_proba = base_rf.predict_proba(X_oos)[:, 1]

# %%
threshold_oos = 0.3
plot_confusion_matrix(y_oos, y_oos_proba, threshold_oos)
# Out:
# Recall/True Positive Rate: The model got 86.73% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 18.47% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 2.86% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
(5712+1294)/len(X_oos)
# Out:
# 0.03476129518819525

# %%
mask_oos = y_oos_proba > threshold_oos

# %%
mask_oos_series = pd.Series(mask_oos, index=X_oos.index)
X_oos_alert = X_oos.loc[mask_oos_series]
y_oos_alert = y_oos.loc[mask_oos_series]

# %%
df_pred_alert = generate_pred_df(
    X=X_oos_alert,
    y=y_oos_alert,
    clf=base_rf,
    amount_col='Transaction Amount',
    bin_on='pbad',
    increment_bin_rate=0.025,
    bins=None
)

# %%
df_agg_alert = compute_bin_aggregates(df_pred_alert)
# Out:
# C:\Users\Administrator\BDI-predator\ml-fraud\src\utils.py:115: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   aggregated_df = pred_df.groupby("bin").agg(agg_cols)

# %%
df_agg_alert[["total_trnx_amt", "good_rate", "bad_rate", "cum_records_passed", "cum_records_rejected", "pass_through_rate"]]
# Out:
#                total_trnx_amt  good_rate  bad_rate  cum_records_passed  \
# bin
# [0.0, 0.025)     0.000000e+00        NaN       NaN                7006
# [0.025, 0.05)    0.000000e+00        NaN       NaN                7006
# [0.05, 0.075)    0.000000e+00        NaN       NaN                7006
# [0.075, 0.1)     0.000000e+00        NaN       NaN                7006
# [0.1, 0.125)     0.000000e+00        NaN       NaN                7006
# [0.125, 0.15)    0.000000e+00        NaN       NaN                7006
# [0.15, 0.175)    0.000000e+00        NaN       NaN                7006
# [0.175, 0.2)     0.000000e+00        NaN       NaN                7006
# [0.2, 0.225)     0.000000e+00        NaN       NaN                7006
# [0.225, 0.25)    0.000000e+00        NaN       NaN                7006
# [0.25, 0.275)    0.000000e+00        NaN       NaN                7006
# [0.275, 0.3)     0.000000e+00        NaN       NaN                7006
# [0.3, 0.325)     5.941380e+08   0.959786  0.040214                7006
# [0.325, 0.35)    8.916789e+08   0.957447  0.042553                6633
# [0.35, 0.375)    1.045166e+09   0.908616  0.091384                6257
# [0.375, 0.4)     7.212405e+08   0.972393  0.027607                5874
# [0.4, 0.425)     7.721456e+08   0.921630  0.078370                5548
