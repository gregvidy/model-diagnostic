# %%
import pandas as pd
import numpy as np
import pyodbc
import sys
import os
from src.utils import read_query_file

project_path = r"C:\Users\Administrator\BDI-predator"

# add path to sys.path if not already added
if project_path not in sys.path:
    sys.path.append(project_path)

pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data Ingestion

# %%
conn = pyodbc.connect(
    "DRIVER={SQL Server};SERVER=10.197.51.166;DATABASE=DataExtractionDB;UID=Predator_ML;PWD=predatorml"
)

# %%
sampling_pct = 0.5 / 100

# %%
# query_og = read_query_file("sql/join_data/02_debit_card_data.sql")
query_new = read_query_file("sql/join_data/02b_debit.sql")
query_new = query_new.format(sampling_pct=sampling_pct)

# %%
# df_debit = pd.read_sql(query_og, conn)
df_debit_new = pd.read_sql(query_new, conn)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\3\ipykernel_6364\1124772204.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_debit_new = pd.read_sql(query_new, conn)

# %%
df_debit_new.to_parquet("data/base/df_debit_all_clean_sample_v1.parquet")

# %%
df_debit_new.Debit_No.nunique()
# Out:
# 24754

# %%
df_debit_new
# Out:
#                                                  Debit_No  \
# 0       b',w\x82U\x94\x17\x1e\xa6mk\x8f\xe1\xc6\xb9\xf...
# 1       b'\xbb\xc5\x11\xbcl\x15]\x1a\xd1\x12r\xb1h\xf9...
# 2       b'0w\xe4Ro\xca+\xa1\xa4Y\xf8\x98\x8a\x0f\xdf\x...
# 3       b'0w\xe4Ro\xca+\xa1\xa4Y\xf8\x98\x8a\x0f\xdf\x...
# 4       b'0w\xe4Ro\xca+\xa1\xa4Y\xf8\x98\x8a\x0f\xdf\x...
# ...                                                   ...
# 334630  b'\xf2)[&ds\x82\xd4\xf8"N\x15\x00W4I\xc6\x84\x...
# 334631  b'\x8f\xeeaI\x9c\x91"\xdc\xd1l\xede\x8fq5\x18&...
# 334632  b'\xda\x96\x9fT>@\xe3]\xa1\x9aE\x81!4\xa1<\xfa...
# 334633  b'n\xf2\xa9\xc5V\x15A\xcaU\xf5\xa7v\xa7\xd7a\x...
# 334634  b"8!\xfc\xcfx\xc1'\x88\xa9rb\t\x7f\xac\xc5f7\x...
#
#         Transaction Serial No Transaction Datetime  Transaction Amount   MCC  \
# 0                   967448932  2024-08-31 00:21:43           4325000.0  6014
# 1                   967770884  2024-08-31 00:23:26             19500.0  6017
# 2                   967449687  2024-08-31 00:32:21            150000.0  6011
# 3                   967449785  2024-08-31 00:33:29           1900000.0  6011
# 4                   967449853  2024-08-31 00:34:19             50000.0  6011
# ...                       ...                  ...                 ...   ...
# 334630             1143905448  2025-05-26 22:33:35                 0.0  None
# 334631             1143905596  2025-05-26 22:34:34                 0.0  None
# 334632             1143913275  2025-05-26 23:33:16                 NaN  6011
# 334633             1143898855  2025-05-26 21:54:20                 NaN  None
# 334634             1143914002  2025-05-26 23:39:09                 0.0  None
#
#        Country Code Card Acceptor Terminal ID      Card Acceptor Name  \
# 0               IDN                  99102000  MANDIRI CASH MANAGEMEN
# 1               IDN                  POS00008             Gopay-Gojek
# 2               IDN                  00001405            BDI SUDIRMAN
# 3               IDN                  80000149      JL. JEND. SUDIRMAN
# 4               IDN                  80000149      JL. JEND. SUDIRMAN
# ...             ...                       ...                     ...
# 334630         None                      None                    None
# 334631         None                      None                    None
# 334632          IDN                  80000836    JL. HM. RAFII MADURE
# 334633         None                      None                    None
# 334634         None                      None                    None
#
#        Card Acceptor City Card Acceptor Region Card Acceptor Country Code  \
# 0            MANDIRI CASH                  021                        IDN
# 1             DKI Jakarta                  000                        IDN
# 2              PURWOKERTO                  000                        IDN
# 3              PURWOKERTO                                             IDN
# 4              PURWOKERTO                                             IDN
# ...                   ...                  ...                        ...
# 334630               None                 None                       None
# 334631               None                 None                       None
# 334632      PANGKALAN BUN                                             IDN
# 334633               None                 None                       None
# 334634               None                 None                       None
#
#        Currency Code  CustomerAge AccountStatus CustomerAvgIncome CardStatus  \
# 0                360          NaN          None              None       None
# 1                360         24.0             8              None          2
# 2                360         31.0             8              None          2
# 3                360         31.0             8              None          2
# 4                360         31.0             8              None          2
# ...              ...          ...           ...               ...        ...
# 334630           360          NaN          None              None       None
# 334631           360          NaN          None              None       None
# 334632           360         32.0             8              None          2
# 334633           360         35.0             8              None          2
# 334634           360          NaN          None              None       None
#
#            Balance  AgeOfOpenAcctTxn  AgeOfActiveCardTxn  \
# 0              NaN               NaN                 NaN
# 1        170000.00               NaN                 NaN
# 2       1871304.82            4687.0               550.0
# 3       1871304.82            4687.0               550.0
# 4       1871304.82            4687.0               550.0
# ...            ...               ...                 ...
# 334630         NaN               NaN                 NaN
# 334631         NaN               NaN                 NaN
# 334632     4669.15            2687.0               801.0
# 334633  1492467.46               NaN                 NaN
# 334634         NaN               NaN                 NaN
#
#        AgeOfOpenAcctActiveCard TrfToBDIStaff BDIStaff AgeOfRegDateTxn  \
# 0                         None          None     None            None
# 1                         None          None        N            None
# 2                         None          None        N            None
# 3                         None          None        N            None
# 4                         None          None        N            None
# ...                        ...           ...      ...             ...
# 334630                    None          None     None            None
# 334631                    None          None     None            None
# 334632                    None          None        N            None
# 334633                    None          None        N            None
# 334634                    None          None     None            None
#
#        IsSDBPastDue FlagOutBranch isTDHoldAmount isProgramHoldAmount  \
# 0              None          None           None                None
# 1              None          None           None                None
# 2              None          None           None                None
# 3              None          None           None                None
# 4              None          None           None                None
# ...             ...           ...            ...                 ...
# 334630         None          None           None                None
# 334631         None          None           None                None
# 334632         None          None           None                None
# 334633         None          None           None                None
# 334634         None          None           None                None
#
#        IsOfficeHour VALAS ChannelTrx LastTrxAmount DrLastTrxAmount  \
# 0              None  None       None          None            None
# 1              None  None       None          None            None
# 2              None  None       None          None            None
# 3              None  None       None          None            None
# 4              None  None       None          None            None
# ...             ...   ...        ...           ...             ...
# 334630         None  None       None          None            None
# 334631         None  None       None          None            None
# 334632         None  None       None          None            None
# 334633         None  None       None          None            None
# 334634         None  None       None          None            None
#
#        CrLastTrxAmount  TotalTrxAmountL1D DrTotalTrxAmountL1D  \
# 0                 None          4625000.0                None
# 1                 None            52500.0                None
# 2                 None           150000.0                None
# 3                 None          2050000.0                None
# 4                 None          2100000.0                None
# ...                ...                ...                 ...
# 334630            None                0.0                None
# 334631            None                0.0                None
# 334632            None                NaN                None
# 334633            None          1281292.0                None
# 334634            None                0.0                None
#
#        CrTotalTrxAmountL1D TotalTrxAmountL7D DrTotalTrxAmountL7D  \
# 0                     None              None                None
# 1                     None              None                None
# 2                     None              None                None
# 3                     None              None                None
# 4                     None              None                None
# ...                    ...               ...                 ...
# 334630                None              None                None
# 334631                None              None                None
# 334632                None              None                None
# 334633                None              None                None
# 334634                None              None                None
#
#        CrTotalTrxAmountL7D TotalTrxAmountL1M DrTotalTrxAmountL1M  \
# 0                     None              None                None
# 1                     None              None                None
# 2                     None              None                None
# 3                     None              None                None
# 4                     None              None                None
# ...                    ...               ...                 ...
# 334630                None              None                None
# 334631                None              None                None
# 334632                None              None                None
# 334633                None              None                None
# 334634                None              None                None
#
#        CrTotalTrxAmountL1M AvgTrxAmountL1D AvgTrxAmountL7D AvgTrxAmountL1M  \
# 0                     None            None            None            None
# 1                     None            None            None            None
# 2                     None            None            None            None
# 3                     None            None            None            None
# 4                     None            None            None            None
# ...                    ...             ...             ...             ...
# 334630                None            None            None            None
# 334631                None            None            None            None
# 334632                None            None            None            None
# 334633                None            None            None            None
# 334634                None            None            None            None
#
#         TotalTrxAmount15Mi HIghRiskCustomer ProductName PrevAccStatus  \
# 0                4325000.0             None        None          None
# 1                  19500.0                N        None          None
# 2                 150000.0                N        None          None
# 3                2050000.0                N        None          None
# 4                2100000.0                N        None          None
# ...                    ...              ...         ...           ...
# 334630                 0.0             None        None          None
# 334631                 0.0             None        None          None
# 334632                 NaN                N        None          None
# 334633                 NaN                N        None          None
# 334634                 0.0             None        None          None
#
#        HoldAmountTB HoldAmountDP SDBBalance CCBrnAccount  \
# 0              None         None       None         None
# 1              None         None       None          891
# 2              None         None       None          702
# 3              None         None       None          702
# 4              None         None       None          702
# ...             ...          ...        ...          ...
# 334630         None         None       None         None
# 334631         None         None       None         None
# 334632         None         None       None          521
# 334633         None         None       None          373
# 334634         None         None       None         None
#
#        CCBrnReactivedAccDormant BrnNameReactivedAccDormant TrxBranchName  \
# 0                          None                       None          None
# 1                          None                       None          None
# 2                          None                       None          None
# 3                          None                       None          None
# 4                          None                       None          None
# ...                         ...                        ...           ...
# 334630                     None                       None          None
# 334631                     None                       None          None
# 334632                     None                       None          None
# 334633                     None                       None          None
# 334634                     None                       None          None
#
#        IsWhiteList IsBlacklistAccount IsBlacklistCust ProductCodeTo  \
# 0             None                  N            None          None
# 1             None                  N            None          None
# 2             None               None            None          None
# 3             None               None            None          None
# 4             None               None            None          None
# ...            ...                ...             ...           ...
# 334630        None                  N            None          None
# 334631        None                  N            None          None
# 334632        None               None            None          None
# 334633        None                  N            None          None
# 334634        None                  N            None          None
#
#        AccessCode SDBBoxNo SDBStatus SDBLastPaymentAmount FlagTxnDesc  \
# 0            None     None      None                 None        None
# 1            1000     None      None                 None        None
# 2            None     None      None                 None        None
# 3            None     None      None                 None        None
# 4            None     None      None                 None        None
# ...           ...      ...       ...                  ...         ...
# 334630       None     None      None                 None        None
# 334631       None     None      None                 None        None
# 334632       None     None      None                 None        None
# 334633       None     None      None                 None        None
# 334634       None     None      None                 None        None
#
#        ProductCodeDep IsMerchantBDI  NumOfTrxL1D NumOfTrxL7D  \
# 0                None          None          0.0        None
# 1                None          None          0.0        None
# 2                None          None          1.0        None
# 3                None          None          2.0        None
# 4                None          None          3.0        None
# ...               ...           ...          ...         ...
# 334630           None          None          0.0        None
# 334631           None          None          0.0        None
# 334632           None          None          0.0        None
# 334633           None          None          0.0        None
# 334634           None          None          0.0        None
#
#        IsHighRiskCountry IsBlacklistMerchant IsWatchListMerchant  \
# 0                   None                None                   N
# 1                   None                None                   N
# 2                      N                   N                   N
# 3                      N                   N                   N
# 4                      N                   N                   N
# ...                  ...                 ...                 ...
# 334630              None                None                   N
# 334631              None                None                   N
# 334632                 N                   N                   N
# 334633              None                None                   N
# 334634              None                None                   N
#
#        IsHighRiskMCC CreditLimit CashCreditLimit CardProduct CustomerSex  \
# 0               None        None            None        None        None
# 1               None        None            None          30           F
# 2               None        None            None          71           M
# 3               None        None            None          71           M
# 4               None        None            None          71           M
# ...              ...         ...             ...         ...         ...
# 334630          None        None            None        None        None
# 334631          None        None            None        None        None
# 334632          None        None            None          51           M
# 334633          None        None            None          30           M
# 334634          None        None            None        None        None
#
#        IsBlacklistCardNo IsValidCard Currency POSMode PINEntryCapability  \
# 0                   None        None     None      2                   S
# 1                   None        None     None      1                   1
# 2                      N        None      IDR      5                   0
# 3                      N        None      IDR      5                   0
# 4                      N        None      IDR      5                   0
# ...                  ...         ...      ...     ...                ...
# 334630              None        None     None    None               None
# 334631              None        None     None    None               None
# 334632                 N        None      IDR      5                   0
# 334633              None        None     None    None               None
# 334634              None        None     None    None               None
#
#        IsCardExpired Is3DSecure IsWhiteListMerchant IsBDIEmail  \
# 0               None       None                   N          N
# 1               None       None                   N          N
# 2               None       None                   N          N
# 3               None       None                   N          N
# 4               None       None                   N          N
# ...              ...        ...                 ...        ...
# 334630          None       None                   N          N
# 334631          None       None                   N          N
# 334632          None       None                   N          N
# 334633          None       None                   N          N
# 334634          None       None                   N          N
#
#        IsWhiteListCardNo IsWhiteListAccountNo IsWatchListAccountNo  \
# 0                      N                    N                    N
# 1                      N                    N                    N
# 2                   None                 None                 None
# 3                   None                 None                 None
# 4                   None                 None                 None
# ...                  ...                  ...                  ...
# 334630                 N                    N                    N
# 334631                 N                    N                    N
# 334632              None                 None                 None
# 334633                 N                    N                    N
# 334634                 N                    N                    N
#
#        IsAccountBDIEmployee CodAccess TransactionType  TotalTrxAmount10Mi  \
# 0                      None      None              23           4325000.0
# 1                      None      None              00             19500.0
# 2                      None      None              40            150000.0
# 3                      None      None              01           2050000.0
# 4                      None      None              01           2100000.0
# ...                     ...       ...             ...                 ...
# 334630                 None      None              BI                 0.0
# 334631                 None      None              BI                 0.0
# 334632                 None      None              31                 NaN
# 334633                 None      None              in                 NaN
# 334634                 None      None              BI                 0.0
#
#        CustomerType  TotalTrxAmountL5min  TotalTrxAmountContactless  \
# 0              None            4325000.0                        NaN
# 1              None              19500.0                        NaN
# 2              None             150000.0                        NaN
# 3              None            2050000.0                        NaN
# 4              None            2100000.0                        NaN
# ...             ...                  ...                        ...
# 334630         None                  0.0                        NaN
# 334631         None                  0.0                        NaN
# 334632         None                  NaN                        NaN
# 334633         None                  NaN                        NaN
# 334634         None                  0.0                        NaN
#
#        IsWhitelistCardNoOpen DaysOfWhitelistCardNoOpen IsVAAccount  \
# 0                       None                      None        None
# 1                       None                      None        None
# 2                       None                      None           N
# 3                       None                      None           N
# 4                       None                      None           N
# ...                      ...                       ...         ...
# 334630                  None                      None        None
# 334631                  None                      None        None
# 334632                  None                      None           N
# 334633                  None                      None        None
# 334634                  None                      None        None
#
#        IsExcludeTeminalId isBDICard IsWatchlistCardNo SourceChannel  \
# 0                    None      None              None          None
# 1                    None      None              None          None
# 2                       N         Y              None          None
# 3                       N         Y              None          None
# 4                       N         Y              None          None
# ...                   ...       ...               ...           ...
# 334630               None      None              None          None
# 334631               None      None              None          None
# 334632                  N         Y              None          None
# 334633               None      None              None          None
# 334634               None      None              None          None
#
#        IsBlackListTID IsFirstTrx3DS VCardDataInputCapability  \
# 0                None          None                     None
# 1                None          None                     None
# 2                None          None                        5
# 3                None          None                        5
# 4                None          None                        5
# ...               ...           ...                      ...
# 334630           None          None                     None
# 334631           None          None                     None
# 334632           None          None                        5
# 334633           None          None                     None
# 334634           None          None                     None
#
#        CustomerNationality  TotalTrxAmountContactlessPerDay IsTopUp  \
# 0                     None                              NaN       N
# 1                       ID                              NaN       Y
# 2                     None                              NaN    None
# 3                     None                              NaN    None
# 4                     None                              NaN    None
# ...                    ...                              ...     ...
# 334630                None                              NaN       N
# 334631                None                              NaN       N
# 334632                None                              NaN    None
# 334633                  ID                              NaN       N
# 334634                None                              NaN       N
#
#        IsBillPayment IsPaymentToVA  TotalTrxAmountTopUp1  \
# 0                  N             N                   NaN
# 1                  N             N                   NaN
# 2               None          None                   NaN
# 3               None          None                   NaN
# 4               None          None                   NaN
# ...              ...           ...                   ...
# 334630             N             N                   NaN
# 334631             N             N                   NaN
# 334632          None          None                   NaN
# 334633             N             N                   NaN
# 334634             N             N                   NaN
#
#         TotalTrxAmountTopUp2  TotalTrxAmountVA1  TotalTrxAmountVA2  \
# 0                        NaN                NaN                NaN
# 1                        NaN                NaN                NaN
# 2                        NaN                NaN                NaN
# 3                        NaN                NaN                NaN
# 4                        NaN                NaN                NaN
# ...                      ...                ...                ...
# 334630                   NaN                NaN                NaN
# 334631                   NaN                NaN                NaN
# 334632                   NaN                NaN                NaN
# 334633                   NaN                NaN          1281292.0
# 334634                   NaN                NaN                NaN
#
#                                      CustomerEwaletNumber  \
# 0       b"\xb9\x07f\x17\xe8'\x1b\xcd\x9b\xe7?\xa2BD\x9...
# 1       b"\xe3\xb0\xc4B\x98\xfc\x1c\x14\x9a\xfb\xf4\xc...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 334630  b'\xc0"\x03aV\xc7]RF2\x03\x1d\xa0\xfe\x91\xedZ...
# 334631  b'\xcd6\x10\x03\x14_s\xc3DN\x18\xf7\xeb\xa5|\x...
# 334632                                               None
# 334633  b'V\x18\xadPF\x08)>\xe8TP\x82\xc04\x08[\xce\xc...
# 334634  b'\\\xe5\xce\xb0\x12\xe4\x1f\xcd\x15\xe9\x02s\...
#
#        IsHighRiskCountryThresholdAmt IsHighRiskCurrency  \
# 0                               None               None
# 1                               None               None
# 2                               None               None
# 3                               None               None
# 4                               None               None
# ...                              ...                ...
# 334630                          None               None
# 334631                          None               None
# 334632                          None               None
# 334633                          None               None
# 334634                          None               None
#
#        IsHighRiskCurrencyThresholdAmt IsQRtrx IsDCashTrx IsFTTrx  \
# 0                                None   N          N           N
# 1                                None   N          N           N
# 2                                None    None       None    None
# 3                                None    None       None    None
# 4                                None    None       None    None
# ...                               ...     ...        ...     ...
# 334630                           None   N          N           N
# 334631                           None   N          N           N
# 334632                           None    None       None    None
# 334633                           None   N          N           N
# 334634                           None   N          N           N
#
#         TotalTrxAmountQRIS  TotalTrxAmountDcash  TotalTrxAmountTrf  \
# 0                      NaN                  NaN                NaN
# 1                      NaN                  NaN                NaN
# 2                      NaN                  NaN                NaN
# 3                      NaN                  NaN                NaN
# 4                      NaN                  NaN                NaN
# ...                    ...                  ...                ...
# 334630                 NaN                  NaN                NaN
# 334631                 NaN                  NaN                NaN
# 334632                 NaN                  NaN                NaN
# 334633                 NaN                  NaN                NaN
# 334634                 NaN                  NaN                NaN
#
#         CountTrxQRIS  CountTrxTrf  TotalTrxAmountTrf2  CountTrxQRIS2  \
# 0                NaN          NaN                 NaN            NaN
# 1                NaN          NaN                 NaN            NaN
# 2                NaN          NaN                 NaN            NaN
# 3                NaN          NaN                 NaN            NaN
# 4                NaN          NaN                 NaN            NaN
# ...              ...          ...                 ...            ...
# 334630           NaN          NaN                 NaN            NaN
# 334631           NaN          NaN                 NaN            NaN
# 334632           NaN          NaN                 NaN            NaN
# 334633           NaN          NaN                 NaN            NaN
# 334634           NaN          NaN                 NaN            NaN
#
#         CountTrxDcash  CountTrxTrf2  NumOfTrxL15Min  \
# 0                 NaN           NaN             0.0
# 1                 NaN           NaN             0.0
# 2                 NaN           NaN             NaN
# 3                 NaN           NaN             NaN
# 4                 NaN           NaN             NaN
# ...               ...           ...             ...
# 334630            NaN           NaN             0.0
# 334631            NaN           NaN             0.0
# 334632            NaN           NaN             NaN
# 334633            NaN           NaN             0.0
# 334634            NaN           NaN             0.0
#
#        IsWhitelistCardNoPrevilage IsWhiteListTID IsWatchListTID  \
# 0                            None           None           None
# 1                            None           None           None
# 2                            None           None           None
# 3                            None           None           None
# 4                            None           None           None
# ...                           ...            ...            ...
# 334630                       None           None           None
# 334631                       None           None           None
# 334632                       None           None           None
# 334633                       None           None           None
# 334634                       None           None           None
#
#         TimeDiffCurrPrev TotalTrxAmount30Mi IsBucket1WatchListCardNo  \
# 0                    NaN               None                     None
# 1                    NaN               None                     None
# 2                    1.0               None                     None
# 3                    1.0               None                     None
# 4                    1.0               None                     None
# ...                  ...                ...                      ...
# 334630               NaN               None                     None
# 334631               NaN               None                     None
# 334632            4590.0               None                     None
# 334633               NaN               None                     None
# 334634               NaN               None                     None
#
#        IsBucket1BlacklistCardNo IsBucket1WhiteListCardNo  \
# 0                          None                     None
# 1                          None                     None
# 2                          None                     None
# 3                          None                     None
# 4                          None                     None
# ...                         ...                      ...
# 334630                     None                     None
# 334631                     None                     None
# 334632                     None                     None
# 334633                     None                     None
# 334634                     None                     None
#
#        IsBucket2WhiteListMerchant IsBucket2WatchListMerchant  \
# 0                            None                       None
# 1                            None                       None
# 2                            None                       None
# 3                            None                       None
# 4                            None                       None
# ...                           ...                        ...
# 334630                       None                       None
# 334631                       None                       None
# 334632                       None                       None
# 334633                       None                       None
# 334634                       None                       None
#
#        IsBucket2BlacklistMerchant  CountTrxEOD Confirmed
# 0                            None          NaN      None
# 1                            None          NaN      None
# 2                            None          0.0      None
# 3                            None          0.0      None
# 4                            None          0.0      None
# ...                           ...          ...       ...
# 334630                       None          NaN      None
# 334631                       None          NaN      None
# 334632                       None          0.0      None
# 334633                       None          NaN      None
# 334634                       None          NaN      None
#
# [334635 rows x 145 columns]

# %%
df_debit.to_parquet("data/base/df_debit_sample_v4.parquet")

# %%
df_debit["Transaction Datetime"] = pd.to_datetime(df_debit["Transaction Datetime"])

# %%
df_debit[
    df_debit["Debit_No"]
    == b"\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):\xc2\x0c\x86\xdf:\xa1W/\xa1\x9fn\x1fmI"
][
    [
        "Debit_No",
        "Transaction Serial No",
        "Transaction Datetime",
        "Transaction Amount",
        "Confirmed",
    ]
].sort_values(
    "Transaction Datetime", ascending=True
)
# Out:
#                                                  Debit_No  \
# 213733  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 256601  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 256667  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 260162  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 262050  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 262011  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 322048  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 325402  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 333477  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 336234  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
# 338006  b'\r\x9e\xf3%\xc5\x1d\n5}\xe5\xd9\x0c\x0cRE5):...
#
#         Transaction Serial No Transaction Datetime  Transaction Amount  \
# 213733             1070784510  2025-01-21 19:03:10             91200.0
# 256601             1087329018  2025-02-20 18:07:25            171050.0
# 256667             1087348103  2025-02-20 19:14:43             38500.0
# 260162             1088640674  2025-02-23 12:27:27            100000.0
# 262050             1089843360  2025-02-24 19:29:02             15000.0
# 262011             1089844992  2025-02-24 19:34:44             21500.0
# 322048             1119102497  2025-04-13 16:14:48            600000.0
# 325402             1120530940  2025-04-16 09:29:07          27820265.0
# 333477             1123644542  2025-04-22 13:24:35           4000000.0
# 336234             1124787441  2025-04-24 14:02:12            118999.0
# 338006             1125579402  2025-04-25 18:45:18          17500000.0
#
#         Confirmed
# 213733        NaN
# 256601        NaN
# 256667        NaN
# 260162        NaN
# 262050        NaN
# 262011        NaN
# 322048        NaN
# 325402        NaN
# 333477        NaN
# 336234        NaN
# 338006        1.0
