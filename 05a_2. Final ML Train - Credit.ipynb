# %%
import pandas as pd
import numpy as np
from src.model_pipeline import ModelPipeline

# %%
df_final = pd.read_parquet("data/feature_engineering/credit/v3/df_credit_final.parquet")
df_final = df_final.set_index("Transaction Serial No", drop=True)

# %% [markdown]
# # Final Drop Columns

# %%
all_feats = [
    "time_diff",
    "POSMode_FE",
    "MCC Category_FE",
    "TransactionType_FE",
    "TxnCount_to_MCC_cat_L90D",
    "Transaction Amount",
    "TxnCount_to_cardAcceptor_cat_L90D",
    "Sum_Amt_to_cardAcceptor_country_L90D",
    "Max_Amt_to_MCC_L90D",
    "Max_Amt_to_cardAcceptor_country_L90D",
    "Sum_Amt_to_MCC_L90D",
    "CntUnique_CardNo_by_cardAcceptor_country_L1H",
    "Cat Card Acceptor Name_FE",
    "Avg_Amt_to_cardAcceptor_country_L90D",
    "CntUnique_CardNo_by_cardAcceptor_cat_L14D",
    "Avg_Amt_to_MCC_L90D",
    "TxnCount_to_countryCode_L90D",
    "TotalTrxAmount30Mi",
    "TotalTrxAmount15Mi",
    "CntUnique_CardNo_by_cardAcceptor_country_L15M",
    "CntUnique_CardNo_by_cardAcceptor_cat_L30D",
    "TotalTrxAmountL5min",
    "TotalTrxAmount10Mi",
    "Sum_Amt_to_cardAcceptor_cat_L90D",
    "CntUnique_CardNo_by_cardAcceptor_cat_L7D",
    "Max_Amt_to_MCC_cat_L90D",
    "TxnCount_to_countryCode_L30D",
    "Sum_Amt_to_MCC_cat_L90D",
    "Sum_Amt_to_cardAcceptor_country_L30D",
    "Max_Amt_to_cardAcceptor_cat_L90D",
    "CntUnique_CardNo_by_cardAcceptor_cat_L1D",
    "Avg_Amt_to_MCC_cat_L90D",
    "TxnCount_L90D",
    "Avg_Amt_to_cardAcceptor_cat_L90D",
    "TxnCount_to_MCC_catcode_L90D",
    "Max_Amt_L15M",
    "Avg_Amt_to_cardAcceptor_country_L30D",
    "PINEntryCapability_FE",
    "Max_Amt_to_cardAcceptor_country_L30D",
    "TxnCount_L30D",
    "Max_Amt_to_MCC_L30D",
    "TotalTrxAmountL1D",
    "Max_Amt_to_cardAcceptor_country_L14D",
    "Sum_Amt_to_MCC_cat_L30D",
    "Currency_FE",
    "Max_Amt_L1H",
    "Sum_Amt_to_cardAcceptor_country_L15M",
    "TxnCount_to_MCC_catcode_L30D",
    "Max_Amt_to_cardAcceptor_cat_L30D",
    "Sum_Amt_to_MCC_L30D",
    "Max_Amt_to_cardAcceptor_country_L1H",
    "Max_Amt_to_cardAcceptor_country_L15M",
    "Max_Amt_to_MCC_cat_L30D",
    "CntUnique_CardNo_by_MCC_L1D",
    "Avg_Amt_to_MCC_cat_L30D",
    "Avg_Amt_to_MCC_L30D",
    "Sum_Amt_to_cardAcceptor_country_L1H",
    "Sum_Amt_to_cardAcceptor_country_L14D",
    "Sum_Amt_to_countryCode_L15M",
    "Avg_Amt_to_cardAcceptor_country_L14D",
    "Avg_Amt_to_cardAcceptor_country_L7D",
    "Avg_Amt_to_cardAcceptor_cat_L30D",
    "Sum_Amt_to_cardAcceptor_cat_L30D",
    "Sum_Amt_to_MCC_cat_L1H",
    "Max_Amt_to_countryCode_L1H",
    "Max_Amt_to_MCC_cat_L15M",
    "Country Code_FE",
    "CardProduct_FE",
    "Avg_Amt_to_cardAcceptor_country_L15M",
    "Max_Amt_to_cardAcceptor_country_L7D",
    "Max_Amt_to_countryCode_L15M",
    "Sum_Amt_to_MCC_cat_L15M",
    "Avg_Amt_L15M",
    "Max_Amt_to_MCC_L14D",
    "Max_Amt_to_MCC_cat_L1H",
    "VCardDataInputCapability_FE",
    "Sum_Amt_to_cardAcceptor_country_L1D",
    "Sum_Amt_to_MCC_L14D",
    "Max_Amt_L1D",
    "Avg_Amt_to_cardAcceptor_cat_L14D",
    "Avg_Amt_to_MCC_cat_L14D",
    "Sum_Amt_to_cardAcceptor_cat_L15M",
    "Max_Amt_to_MCC_cat_L14D",
    "Max_Amt_to_cardAcceptor_cat_L14D",
    "Max_Amt_to_cardAcceptor_country_L1D",
    "Max_Amt_to_MCC_cat_L7D",
    "Max_Amt_to_cardAcceptor_cat_L15M",
    "Avg_Amt_to_MCC_L14D",
    "SourceChannel_FE",
    "Sum_Amt_to_MCC_cat_L14D",
    "Avg_Amt_to_cardAcceptor_cat_L7D",
    "Max_Amt_to_cardAcceptor_cat_L7D",
    "Max_Amt_to_countryCode_L1D",
    "Max_Amt_to_MCC_L7D",
    "Sum_Amt_to_cardAcceptor_cat_L14D",
    "Sum_Amt_to_MCC_cat_L7D",
    "Sum_Amt_to_MCC_L7D",
    "Max_Amt_to_cardAcceptor_cat_L1D",
    "Sum_Amt_to_cardAcceptor_cat_L7D",
    "Max_Amt_to_MCC_L1H",
    "Max_Amt_to_MCC_cat_L1D",
    "Avg_Amt_to_MCC_cat_L7D",
    "CustomerSex_FE",
    "Avg_Amt_to_MCC_L7D",
    "Avg_Amt_to_MCC_cat_L15M",
    "Sum_Amt_to_MCC_cat_L1D",
    "Currency Code_FE",
    "Max_Amt_to_MCC_L15M",
    "Max_Amt_to_MCC_L1D",
    "Sum_Amt_to_MCC_L15M",
    "CardStatus_FE",
    "Sum_Amt_to_MCC_L1H",
    "Sum_Amt_to_cardAcceptor_cat_L1H",
    "Max_Amt_to_cardAcceptor_cat_L1H",
    "AccountStatus_FE",
    "CustomerNationality_FE",
]

# %%
derived_cols = [
    "Avg_Amt_L15M",
    "Avg_Amt_to_MCC_L14D",
    "Avg_Amt_to_MCC_L30D",
    "Avg_Amt_to_MCC_L7D",
    "Avg_Amt_to_MCC_L90D",
    "CntUnique_CardNo_by_MCC_L1D",
    "Max_Amt_L15M",
    "Max_Amt_L1D",
    "Max_Amt_L1H",
    "Max_Amt_to_MCC_L14D",
    "Max_Amt_to_MCC_L15M",
    "Max_Amt_to_MCC_L1D",
    "Max_Amt_to_MCC_L1H",
    "Max_Amt_to_MCC_L30D",
    "Max_Amt_to_MCC_L7D",
    "Max_Amt_to_MCC_L90D",
    "Max_Amt_to_countryCode_L15M",
    "Max_Amt_to_countryCode_L1D",
    "Max_Amt_to_countryCode_L1H",
    "Sum_Amt_to_MCC_L14D",
    "Sum_Amt_to_MCC_L15M",
    "Sum_Amt_to_MCC_L1H",
    "Sum_Amt_to_MCC_L30D",
    "Sum_Amt_to_MCC_L7D",
    "Sum_Amt_to_MCC_L90D",
    "Sum_Amt_to_countryCode_L15M",
    "TxnCount_L30D",
    "TxnCount_L90D",
    "TxnCount_to_countryCode_L30D",
    "TxnCount_to_countryCode_L90D",
    "time_diff",
]

# %%
non_derived_cols = [
    # 'AccountStatus', dropped due to low importance
    "CardProduct",
    "CardStatus",
    # 'Cat Card Acceptor Name', coming from string -> hard to replicate the login in MLM
    # 'Country Code', dropped due to high cardinality
    "Currency Code",
    # 'CustomerNationality', dropped due to high cardinality
    "CustomerSex",
    "MCC Category",
    # 'PINEntryCapability', dropped due to low importance
    "POSMode",
    # 'SourceChannel', dropped due to high missing value
    "TotalTrxAmount10Mi",
    "TotalTrxAmount15Mi",
    "TotalTrxAmount30Mi",
    "TotalTrxAmountL1D",
    "TotalTrxAmountL5min",
    "Transaction Amount",
    # 'TransactionType', dropped due to low importance
    # 'VCardDataInputCapability' dropped due to low importance
]

# %%
selected_derived_cols = [
    col for col in derived_cols if any(substr in col for substr in ["L15M", "L30D"])
] + ["time_diff"]

# %%
selected_derived_cols
# Out:
# ['Avg_Amt_L15M',
#  'Avg_Amt_to_MCC_L30D',
#  'Max_Amt_L15M',
#  'Max_Amt_to_MCC_L15M',
#  'Max_Amt_to_MCC_L30D',
#  'Max_Amt_to_countryCode_L15M',
#  'Sum_Amt_to_MCC_L15M',
#  'Sum_Amt_to_MCC_L30D',
#  'Sum_Amt_to_countryCode_L15M',
#  'TxnCount_L30D',
#  'TxnCount_to_countryCode_L30D',
#  'time_diff']

# %%
final_feats = (
    selected_derived_cols + non_derived_cols + ["Transaction Datetime", "Confirmed"]
)

# %%
len(selected_derived_cols), len(non_derived_cols), len(
    selected_derived_cols + non_derived_cols
)
# Out:
# (12, 12, 24)

# %%
(selected_derived_cols + non_derived_cols)
# Out:
# ['Avg_Amt_L15M',
#  'Avg_Amt_to_MCC_L30D',
#  'Max_Amt_L15M',
#  'Max_Amt_to_MCC_L15M',
#  'Max_Amt_to_MCC_L30D',
#  'Max_Amt_to_countryCode_L15M',
#  'Sum_Amt_to_MCC_L15M',
#  'Sum_Amt_to_MCC_L30D',
#  'Sum_Amt_to_countryCode_L15M',
#  'TxnCount_L30D',
#  'TxnCount_to_countryCode_L30D',
#  'time_diff',
#  'CardProduct',
#  'CardStatus',
#  'Currency Code',
#  'CustomerSex',
#  'MCC Category',
#  'POSMode',
#  'TotalTrxAmount10Mi',
#  'TotalTrxAmount15Mi',
#  'TotalTrxAmount30Mi',
#  'TotalTrxAmountL1D',
#  'TotalTrxAmountL5min',
#  'Transaction Amount']

# %%
df_final = df_final[final_feats]

# %% [markdown]
# ## Create Ratio Features

# %%
def create_ratio_features(
    df: pd.DataFrame, feature_list: list, default_value: float = -999
) -> pd.DataFrame:
    """
    Automatically creates ratio features of the form L30D, L15M
    for matching base features from the provided feature list
    """
    l15m_feats = {
        col.replace("_L15M", ""): col for col in feature_list if "_L15M" in col
    }
    l30d_feats = {
        col.replace("_L30D", ""): col for col in feature_list if "_L30D" in col
    }

    # find matching base feature names
    matching_bases = set(l15m_feats.keys()) & set(l30d_feats.keys())

    # create ratio columns
    for base in matching_bases:
        col_15m = l15m_feats[base]
        col_30d = l30d_feats[base]
        new_col = f"ratio_{base.lower()}_L30D_L15M"

        # calculate the ratio with save division
        ratio = df[col_30d] / df[col_15m]
        ratio = ratio.replace([np.inf, -np.inf], np.nan)  # handle div by zero

        # fill 0/0 or NaNs or infinities with default value
        df[new_col] = ratio.fillna(default_value)

    return df

# %%
df_final = create_ratio_features(df_final, selected_derived_cols)

# %%
# ratio 1
df_final["RatioTrxAmountL1DL5min"] = (
    df_final["TotalTrxAmountL1D"] / df_final["TotalTrxAmountL5min"]
)
df_final["RatioTrxAmountL1DL5min"] = df_final["RatioTrxAmountL1DL5min"].replace(
    [np.inf, -np.inf], np.nan
)
df_final["RatioTrxAmountL1DL5min"] = df_final["RatioTrxAmountL1DL5min"].fillna(-999)

# ratio 2
df_final["RatioTrxAmountL1DL15min"] = (
    df_final["TotalTrxAmountL1D"] / df_final["TotalTrxAmount15Mi"]
)
df_final["RatioTrxAmountL1DL15min"] = df_final["RatioTrxAmountL1DL15min"].replace(
    [np.inf, -np.inf], np.nan
)
df_final["RatioTrxAmountL1DL15min"] = df_final["RatioTrxAmountL1DL15min"].fillna(-999)

# ratio 3
df_final["RatioTrxAmountL1DL10min"] = (
    df_final["TotalTrxAmountL1D"] / df_final["TotalTrxAmount10Mi"]
)
df_final["RatioTrxAmountL1DL10min"] = df_final["RatioTrxAmountL1DL10min"].replace(
    [np.inf, -np.inf], np.nan
)
df_final["RatioTrxAmountL1DL10min"] = df_final["RatioTrxAmountL1DL10min"].fillna(-999)

# ratio 4
df_final["RatioTrxAmountL1DL30min"] = (
    df_final["TotalTrxAmountL1D"] / df_final["TotalTrxAmount30Mi"]
)
df_final["RatioTrxAmountL1DL30min"] = df_final["RatioTrxAmountL1DL30min"].replace(
    [np.inf, -np.inf], np.nan
)
df_final["RatioTrxAmountL1DL30min"] = df_final["RatioTrxAmountL1DL30min"].fillna(-999)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1398828 entries, 1040632171 to 1143982349
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Avg_Amt_L15M                    1394534 non-null  float64
#  1   Avg_Amt_to_MCC_L30D             1394534 non-null  float64
#  2   Max_Amt_L15M                    1394534 non-null  float64
#  3   Max_Amt_to_MCC_L15M             1394534 non-null  float64
#  4   Max_Amt_to_MCC_L30D             1394534 non-null  float64
#  5   Max_Amt_to_countryCode_L15M     1394534 non-null  float64
#  6   Sum_Amt_to_MCC_L15M             1394534 non-null  float64
#  7   Sum_Amt_to_MCC_L30D             1394534 non-null  float64
#  8   Sum_Amt_to_countryCode_L15M     1394534 non-null  float64
#  9   TxnCount_L30D                   1394534 non-null  float64
#  10  TxnCount_to_countryCode_L30D    1394514 non-null  float64
#  11  time_diff                       1360026 non-null  float64
#  12  CardProduct                     1172057 non-null  string
#  13  CardStatus                      1172057 non-null  string
#  14  Currency Code                   1398828 non-null  string
#  15  CustomerSex                     1160868 non-null  string
#  16  MCC Category                    1263317 non-null  string
#  17  POSMode                         1268245 non-null  string
#  18  TotalTrxAmount10Mi              1208897 non-null  float64
#  19  TotalTrxAmount15Mi              1208914 non-null  float64
#  20  TotalTrxAmount30Mi              1040922 non-null  float64
#  21  TotalTrxAmountL1D               1209740 non-null  float64
#  22  TotalTrxAmountL5min             1208883 non-null  float64
#  23  Transaction Amount              1387919 non-null  float64
#  24  Transaction Datetime            1398828 non-null  datetime64[ns]
#  25  Confirmed                       1398828 non-null  bool
#  26  ratio_max_amt_to_mcc_L30D_L15M  1398828 non-null  float64
#  27  ratio_sum_amt_to_mcc_L30D_L15M  1398828 non-null  float64
#  28  RatioTrxAmountL1DL5min          1398828 non-null  float64
#  29  RatioTrxAmountL1DL15min         1398828 non-null  float64
#  30  RatioTrxAmountL1DL10min         1398828 non-null  float64
#  31  RatioTrxAmountL1DL30min         1398828 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(24), string(6)
# memory usage: 342.8 MB

# %% [markdown]
# ## Modify Grouping of CardProduct

# %%
def standardize_to_string_int(val):
    if val == "__missing__":
        return "__missing__"
    try:
        numeric_val = float(val)
        if numeric_val == int(numeric_val):
            return str(int(numeric_val))
        else:
            return str(numeric_val)
    except (ValueError, TypeError):
        return str(val)


def get_card_product_group(val):
    if val == "__missing__":
        return "__missing__"

    s_val = str(val)

    if len(s_val) > 0 and s_val[0].isdigit():
        first_digit = int(s_val[0])
        if 1 <= first_digit <= 7:
            return f"card_product_{first_digit}"
        else:
            return "card_product_other"

    else:
        return "card_product_other"

# %%
df_final["CardProduct"] = df_final["CardProduct"].fillna("__missing__")
df_final["CardProduct"] = df_final["CardProduct"].apply(standardize_to_string_int)
df_final["CardProductGrouped"] = df_final["CardProduct"].apply(get_card_product_group)

# %% [markdown]
# ## Modify Grouping Currency Code

# %%
specific_currency_code = ["360", "840", "702", "392", "978", "036", "764"]

# %%
df_final["CurrencyCodeGroup"] = np.where(
    df_final["Currency Code"].isin(specific_currency_code),
    df_final["Currency Code"],
    "others",
)

# %%
df_final.drop(["CardProduct", "Currency Code"], axis=1, inplace=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1398828 entries, 1040632171 to 1143982349
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Avg_Amt_L15M                    1394534 non-null  float64
#  1   Avg_Amt_to_MCC_L30D             1394534 non-null  float64
#  2   Max_Amt_L15M                    1394534 non-null  float64
#  3   Max_Amt_to_MCC_L15M             1394534 non-null  float64
#  4   Max_Amt_to_MCC_L30D             1394534 non-null  float64
#  5   Max_Amt_to_countryCode_L15M     1394534 non-null  float64
#  6   Sum_Amt_to_MCC_L15M             1394534 non-null  float64
#  7   Sum_Amt_to_MCC_L30D             1394534 non-null  float64
#  8   Sum_Amt_to_countryCode_L15M     1394534 non-null  float64
#  9   TxnCount_L30D                   1394534 non-null  float64
#  10  TxnCount_to_countryCode_L30D    1394514 non-null  float64
#  11  time_diff                       1360026 non-null  float64
#  12  CardStatus                      1172057 non-null  string
#  13  CustomerSex                     1160868 non-null  string
#  14  MCC Category                    1263317 non-null  string
#  15  POSMode                         1268245 non-null  string
#  16  TotalTrxAmount10Mi              1208897 non-null  float64
#  17  TotalTrxAmount15Mi              1208914 non-null  float64
#  18  TotalTrxAmount30Mi              1040922 non-null  float64
#  19  TotalTrxAmountL1D               1209740 non-null  float64
#  20  TotalTrxAmountL5min             1208883 non-null  float64
#  21  Transaction Amount              1387919 non-null  float64
#  22  Transaction Datetime            1398828 non-null  datetime64[ns]
#  23  Confirmed                       1398828 non-null  bool
#  24  ratio_max_amt_to_mcc_L30D_L15M  1398828 non-null  float64
#  25  ratio_sum_amt_to_mcc_L30D_L15M  1398828 non-null  float64
#  26  RatioTrxAmountL1DL5min          1398828 non-null  float64
#  27  RatioTrxAmountL1DL15min         1398828 non-null  float64
#  28  RatioTrxAmountL1DL10min         1398828 non-null  float64
#  29  RatioTrxAmountL1DL30min         1398828 non-null  float64
#  30  CardProductGrouped              1398828 non-null  object
#  31  CurrencyCodeGroup               1398828 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(24), object(2), string(4)
# memory usage: 342.8+ MB

# %% [markdown]
# # Split and Prepare DF

# %%
split_date = "2025-05-01"

# %%
# setup pipeline
pipeline = ModelPipeline(model_type="xgboost", random_state=42)

df_splits = pipeline.split_data_by_date(
    df=df_final, date_column="Transaction Datetime", split_date=split_date
)
# Out:
# Initializing ModelPipeline with model type: xgboost
# Retrieving model instance for type: xgboost
# Splitting data by date (pre-preprocessing)...
# Train samples: 1197282, Test samples: 201546
# Data splitting complete.

# %%
df_splits["df_train"].Confirmed.value_counts(normalize=True)
# Out:
# Confirmed
# False    0.992576
# True     0.007424
# Name: proportion, dtype: float64

# %%
df_splits["df_test"].Confirmed.value_counts(normalize=True)
# Out:
# Confirmed
# False    0.992597
# True     0.007403
# Name: proportion, dtype: float64

# %%
# prepare TRAIN data
target_col = "Confirmed"
X, y = pipeline.prepare_data(
    df=df_splits["df_train"],
    target_column=target_col,
    exclude_columns=["Transaction Datetime"],
    is_apply_one_hot=False,
    is_apply_log=True,
    is_impute_median=True,
    is_training=True,
)
# Out:
# Preparing data (is_training=True)...
# Starting core numeric and boolean preprocessing...
#   Float columns to downcast: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_Amt_to_countryCo ...
#   Downcasted column: time_diff
#   Downcasted column: TxnCount_L15M
#   Downcasted column: TxnCount_L1H
#   Downcasted column: TxnCount_L1D
#   Downcasted column: TxnCount_L7D
#   Downcasted column: TxnCount_L14D
#   Downcasted column: TxnCount_L30D
#   Downcasted column: TxnCount_L90D
#   Downcasted column: TxnCount_to_MCC_L15M
#   Downcasted column: TxnCount_to_MCC_L1H
#   Downcasted column: TxnCount_to_MCC_L1D
#   Downcasted column: TxnCount_to_MCC_L7D
#   Downcasted column: TxnCount_to_MCC_L14D
#   Downcasted column: TxnCount_to_MCC_L30D
#   Downcasted column: TxnCount_to_MCC_L90D
#   Downcasted column: TxnCount_to_MCC_details_L15M
#   Downcasted column: TxnCount_to_MCC_details_L1H
#   Downcasted column: TxnCount_to_MCC_details_L1D
#   Downcasted column: TxnCount_to_MCC_details_L7D
#   Downcasted column: TxnCount_to_MCC_details_L14D
#   Downcasted column: TxnCount_to_MCC_details_L30D
#   Downcasted column: TxnCount_to_MCC_details_L90D
#   Downcasted column: TxnCount_to_MCC_catcode_L15M
#   Downcasted column: TxnCount_to_MCC_catcode_L1H
#   Downcasted column: TxnCount_to_MCC_catcode_L1D
#   Downcasted column: TxnCount_to_MCC_catcode_L7D
#   Downcasted column: TxnCount_to_MCC_catcode_L14D
#   Downcasted column: TxnCount_to_MCC_catcode_L30D
#   Downcasted column: TxnCount_to_MCC_catcode_L90D
#   Downcasted column: TxnCount_to_MCC_cat_L15M
#   Downcasted column: TxnCount_to_MCC_cat_L1H
#   Downcasted column: TxnCount_to_MCC_cat_L1D
#   Downcasted column: TxnCount_to_MCC_cat_L7D
#   Downcasted column: TxnCount_to_MCC_cat_L14D
#   Downcasted column: TxnCount_to_MCC_cat_L30D
#   Downcasted column: TxnCount_to_MCC_cat_L90D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L15M
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L1H
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L1D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L7D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L14D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L30D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L90D
#   Downcasted column: TxnCount_to_countryCode_L15M
#   Downcasted column: TxnCount_to_countryCode_L1H
#   Downcasted column: TxnCount_to_countryCode_L1D
#   Downcasted column: TxnCount_to_countryCode_L7D
#   Downcasted column: TxnCount_to_countryCode_L14D
#   Downcasted column: TxnCount_to_countryCode_L30D
#   Downcasted column: TxnCount_to_countryCode_L90D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L15M
#   Downcasted column: TxnCount_to_cardAcceptor_country_L1H
#   Downcasted column: TxnCount_to_cardAcceptor_country_L1D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L7D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L14D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L30D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L90D
#   Downcasted column: Avg_Amt_L15M
#   Downcasted column: Avg_Amt_L1H
#   Downcasted column: Avg_Amt_L1D
#   Downcasted column: Avg_Amt_L7D
#   Downcasted column: Avg_Amt_L14D
#   Downcasted column: Avg_Amt_L30D
#   Downcasted column: Avg_Amt_L90D
#   Downcasted column: Max_Amt_L15M
#   Downcasted column: Max_Amt_L1H
#   Downcasted column: Max_Amt_L1D
#   Downcasted column: Max_Amt_L7D
#   Downcasted column: Max_Amt_L14D
#   Downcasted column: Max_Amt_L30D
#   Downcasted column: Max_Amt_L90D
#   Downcasted column: Sum_Amt_L14D
#   Downcasted column: Sum_Amt_L30D
#   Downcasted column: Sum_Amt_L90D
#   Downcasted column: Avg_Amt_to_MCC_L15M
#   Downcasted column: Avg_Amt_to_MCC_L1H
#   Downcasted column: Avg_Amt_to_MCC_L1D
#   Downcasted column: Avg_Amt_to_MCC_L7D
#   Downcasted column: Avg_Amt_to_MCC_L14D
#   Downcasted column: Avg_Amt_to_MCC_L30D
#   Downcasted column: Avg_Amt_to_MCC_L90D
#   Downcasted column: Max_Amt_to_MCC_L15M
#   Downcasted column: Max_Amt_to_MCC_L1H
#   Downcasted column: Max_Amt_to_MCC_L1D
#   Downcasted column: Max_Amt_to_MCC_L7D
#   Downcasted column: Max_Amt_to_MCC_L14D
#   Downcasted column: Max_Amt_to_MCC_L30D
#   Downcasted column: Max_Amt_to_MCC_L90D
#   Downcasted column: Sum_Amt_to_MCC_L15M
#   Downcasted column: Sum_Amt_to_MCC_L1H
#   Downcasted column: Sum_Amt_to_MCC_L1D
#   Downcasted column: Sum_Amt_to_MCC_L7D
#   Downcasted column: Sum_Amt_to_MCC_L14D
#   Downcasted column: Sum_Amt_to_MCC_L30D
#   Downcasted column: Sum_Amt_to_MCC_L90D
#   Downcasted column: Avg_Amt_to_MCC_cat_L15M
#   Downcasted column: Avg_Amt_to_MCC_cat_L1H
#   Downcasted column: Avg_Amt_to_MCC_cat_L1D
#   Downcasted column: Avg_Amt_to_MCC_cat_L7D
#   Downcasted column: Avg_Amt_to_MCC_cat_L14D
#   Downcasted column: Avg_Amt_to_MCC_cat_L30D
#   Downcasted column: Avg_Amt_to_MCC_cat_L90D
#   Downcasted column: Max_Amt_to_MCC_cat_L15M
#   Downcasted column: Max_Amt_to_MCC_cat_L1H
#   Downcasted column: Max_Amt_to_MCC_cat_L1D
#   Downcasted column: Max_Amt_to_MCC_cat_L7D
#   Downcasted column: Max_Amt_to_MCC_cat_L14D
#   Downcasted column: Max_Amt_to_MCC_cat_L30D
#   Downcasted column: Max_Amt_to_MCC_cat_L90D
#   Downcasted column: Sum_Amt_to_MCC_cat_L15M
#   Downcasted column: Sum_Amt_to_MCC_cat_L1H
#   Downcasted column: Sum_Amt_to_MCC_cat_L1D
#   Downcasted column: Sum_Amt_to_MCC_cat_L7D
#   Downcasted column: Sum_Amt_to_MCC_cat_L14D
#   Downcasted column: Sum_Amt_to_MCC_cat_L30D
#   Downcasted column: Sum_Amt_to_MCC_cat_L90D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Avg_Amt_to_countryCode_L15M
#   Downcasted column: Avg_Amt_to_countryCode_L1H
#   Downcasted column: Avg_Amt_to_countryCode_L1D
#   Downcasted column: Avg_Amt_to_countryCode_L7D
#   Downcasted column: Avg_Amt_to_countryCode_L14D
#   Downcasted column: Avg_Amt_to_countryCode_L30D
#   Downcasted column: Avg_Amt_to_countryCode_L90D
#   Downcasted column: Max_Amt_to_countryCode_L15M
#   Downcasted column: Max_Amt_to_countryCode_L1H
#   Downcasted column: Max_Amt_to_countryCode_L1D
#   Downcasted column: Max_Amt_to_countryCode_L7D
#   Downcasted column: Max_Amt_to_countryCode_L14D
#   Downcasted column: Max_Amt_to_countryCode_L30D
#   Downcasted column: Max_Amt_to_countryCode_L90D
#   Downcasted column: Sum_Amt_to_countryCode_L15M
#   Downcasted column: Sum_Amt_to_countryCode_L1H
#   Downcasted column: Sum_Amt_to_countryCode_L1D
#   Downcasted column: Sum_Amt_to_countryCode_L7D
#   Downcasted column: Sum_Amt_to_countryCode_L14D
#   Downcasted column: Sum_Amt_to_countryCode_L30D
#   Downcasted column: Sum_Amt_to_countryCode_L90D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: CntUnique_MCC_by_CardNo_L15M
#   Downcasted column: CntUnique_MCC_by_CardNo_L1H
#   Downcasted column: CntUnique_MCC_by_CardNo_L1D
#   Downcasted column: CntUnique_MCC_by_CardNo_L7D
#   Downcasted column: CntUnique_MCC_by_CardNo_L14D
#   Downcasted column: CntUnique_MCC_by_CardNo_L30D
#   Downcasted column: CntUnique_MCC_by_CardNo_L90D
#   Downcasted column: CntUnique_CardNo_by_MCC_L15M
#   Downcasted column: CntUnique_CardNo_by_MCC_L1H
#   Downcasted column: CntUnique_CardNo_by_MCC_L1D
#   Downcasted column: CntUnique_CardNo_by_MCC_L7D
#   Downcasted column: CntUnique_CardNo_by_MCC_L14D
#   Downcasted column: CntUnique_CardNo_by_MCC_L30D
#   Downcasted column: CntUnique_CardNo_by_MCC_L90D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L15M
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L1H
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L1D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L7D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L14D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L30D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L90D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L15M
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L1H
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L1D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L7D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L14D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L30D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L90D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L15M
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L1H
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L1D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L7D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L14D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L30D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L90D
#   Downcasted column: Transaction Amount
#   Downcasted column: CustomerAge
#   Downcasted column: AgeOfOpenAcctTxn
#   Downcasted column: AgeOfActiveCardTxn
#   Downcasted column: TotalTrxAmountL1D
#   Downcasted column: TotalTrxAmountL7D
#   Downcasted column: TotalTrxAmount15Mi
#   Downcasted column: NumOfTrxL1D
#   Downcasted column: NumOfTrxL7D
#   Downcasted column: CreditLimit
#   Downcasted column: CashCreditLimit
#   Downcasted column: TotalTrxAmount10Mi
#   Downcasted column: TotalTrxAmountL5min
#   Downcasted column: TotalTrxAmountContactless
#   Downcasted column: TotalTrxAmount30Mi
#   Mapping Y/N to 1/0 in column: IsBlacklistCust
#   Mapping Y/N to 1/0 in column: IsHighRiskCountry
#   Mapping Y/N to 1/0 in column: IsBlacklistMerchant
#   Mapping Y/N to 1/0 in column: IsWatchListMerchant
#   Mapping Y/N to 1/0 in column: IsHighRiskMCC
#   Mapping Y/N to 1/0 in column: IsBlacklistCardNo
#   Mapping Y/N to 1/0 in column: IsValidCard
#   Mapping Y/N to 1/0 in column: Is3DSecure
#   Mapping Y/N to 1/0 in column: IsWhiteListMerchant
#   Mapping Y/N to 1/0 in column: IsBDIEmail
#   Mapping Y/N to 1/0 in column: IsWhiteListCardNo
#   Mapping Y/N to 1/0 in column: IsWhitelistCardNoOpen
#   Mapping Y/N to 1/0 in column: IsWatchlistCardNo
#   Mapping Y/N to 1/0 in column: IsBlackListTID
#   Mapping Y/N to 1/0 in column: IsFirstTrx3DS
#   Mapping Y/N to 1/0 in column: IsHighRiskCountryThresholdAmt
#   Mapping Y/N to 1/0 in column: IsHighRiskCurrency
#   Mapping Y/N to 1/0 in column: IsHighRiskCurrencyThresholdAmt
#   Mapping Y/N to 1/0 in column: IsWhitelistCardNoPrevilage
#   Mapping Y/N to 1/0 in column: IsWhiteListTID
#   Mapping Y/N to 1/0 in column: IsWatchListTID
#   Mapping Y/N to 1/0 in column: IsBucket1WatchListCardNo
#   Mapping Y/N to 1/0 in column: IsBucket1BlacklistCardNo
#   Mapping Y/N to 1/0 in column: IsBucket1WhiteListCardNo
#   Mapping Y/N to 1/0 in column: IsBucket2WhiteListMerchant
#   Mapping Y/N to 1/0 in column: IsBucket2WatchListMerchant
#   Mapping Y/N to 1/0 in column: IsBucket2BlacklistMerchant
#   Applying log10 transform to column: Avg_Amt_L15M
#   Log10 transformed column: Avg_Amt_L15M
#   Applying log10 transform to column: Avg_Amt_L1H
#   Log10 transformed column: Avg_Amt_L1H
#   Applying log10 transform to column: Avg_Amt_L1D
#   Log10 transformed column: Avg_Amt_L1D
#   Applying log10 transform to column: Avg_Amt_L7D
#   Log10 transformed column: Avg_Amt_L7D
#   Applying log10 transform to column: Avg_Amt_L14D
#   Log10 transformed column: Avg_Amt_L14D
#   Applying log10 transform to column: Avg_Amt_L30D
#   Log10 transformed column: Avg_Amt_L30D
#   Applying log10 transform to column: Avg_Amt_L90D
#   Log10 transformed column: Avg_Amt_L90D
#   Applying log10 transform to column: Max_Amt_L15M
#   Log10 transformed column: Max_Amt_L15M
#   Applying log10 transform to column: Max_Amt_L1H
#   Log10 transformed column: Max_Amt_L1H
#   Applying log10 transform to column: Max_Amt_L1D
#   Log10 transformed column: Max_Amt_L1D
#   Applying log10 transform to column: Max_Amt_L7D
#   Log10 transformed column: Max_Amt_L7D
#   Applying log10 transform to column: Max_Amt_L14D
#   Log10 transformed column: Max_Amt_L14D
#   Applying log10 transform to column: Max_Amt_L30D
#   Log10 transformed column: Max_Amt_L30D
#   Applying log10 transform to column: Max_Amt_L90D
#   Log10 transformed column: Max_Amt_L90D
#   Applying log10 transform to column: Sum_Amt_L14D
#   Log10 transformed column: Sum_Amt_L14D
#   Applying log10 transform to column: Sum_Amt_L30D
#   Log10 transformed column: Sum_Amt_L30D
#   Applying log10 transform to column: Sum_Amt_L90D
#   Log10 transformed column: Sum_Amt_L90D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L15M
#   Log10 transformed column: Avg_Amt_to_MCC_L15M
#   Applying log10 transform to column: Avg_Amt_to_MCC_L1H
#   Log10 transformed column: Avg_Amt_to_MCC_L1H
#   Applying log10 transform to column: Avg_Amt_to_MCC_L1D
#   Log10 transformed column: Avg_Amt_to_MCC_L1D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L7D
#   Log10 transformed column: Avg_Amt_to_MCC_L7D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L14D
#   Log10 transformed column: Avg_Amt_to_MCC_L14D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L30D
#   Log10 transformed column: Avg_Amt_to_MCC_L30D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L90D
#   Log10 transformed column: Avg_Amt_to_MCC_L90D
#   Applying log10 transform to column: Max_Amt_to_MCC_L15M
#   Log10 transformed column: Max_Amt_to_MCC_L15M
#   Applying log10 transform to column: Max_Amt_to_MCC_L1H
#   Log10 transformed column: Max_Amt_to_MCC_L1H
#   Applying log10 transform to column: Max_Amt_to_MCC_L1D
#   Log10 transformed column: Max_Amt_to_MCC_L1D
#   Applying log10 transform to column: Max_Amt_to_MCC_L7D
#   Log10 transformed column: Max_Amt_to_MCC_L7D
#   Applying log10 transform to column: Max_Amt_to_MCC_L14D
#   Log10 transformed column: Max_Amt_to_MCC_L14D
#   Applying log10 transform to column: Max_Amt_to_MCC_L30D
#   Log10 transformed column: Max_Amt_to_MCC_L30D
#   Applying log10 transform to column: Max_Amt_to_MCC_L90D
#   Log10 transformed column: Max_Amt_to_MCC_L90D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L15M
#   Log10 transformed column: Sum_Amt_to_MCC_L15M
#   Applying log10 transform to column: Sum_Amt_to_MCC_L1H
#   Log10 transformed column: Sum_Amt_to_MCC_L1H
#   Applying log10 transform to column: Sum_Amt_to_MCC_L1D
#   Log10 transformed column: Sum_Amt_to_MCC_L1D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L7D
#   Log10 transformed column: Sum_Amt_to_MCC_L7D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L14D
#   Log10 transformed column: Sum_Amt_to_MCC_L14D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L30D
#   Log10 transformed column: Sum_Amt_to_MCC_L30D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L90D
#   Log10 transformed column: Sum_Amt_to_MCC_L90D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Max_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Max_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L15M
#   Log10 transformed column: Avg_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L1H
#   Log10 transformed column: Avg_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L1D
#   Log10 transformed column: Avg_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L7D
#   Log10 transformed column: Avg_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L14D
#   Log10 transformed column: Avg_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L30D
#   Log10 transformed column: Avg_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L90D
#   Log10 transformed column: Avg_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L15M
#   Log10 transformed column: Max_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Max_Amt_to_countryCode_L1H
#   Log10 transformed column: Max_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Max_Amt_to_countryCode_L1D
#   Log10 transformed column: Max_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L7D
#   Log10 transformed column: Max_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L14D
#   Log10 transformed column: Max_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L30D
#   Log10 transformed column: Max_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L90D
#   Log10 transformed column: Max_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L15M
#   Log10 transformed column: Sum_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L1H
#   Log10 transformed column: Sum_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L1D
#   Log10 transformed column: Sum_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L7D
#   Log10 transformed column: Sum_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L14D
#   Log10 transformed column: Sum_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L30D
#   Log10 transformed column: Sum_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L90D
#   Log10 transformed column: Sum_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Transaction Amount
#   Log10 transformed column: Transaction Amount
#   Applying log10 transform to column: TotalTrxAmountL1D
#   Log10 transformed column: TotalTrxAmountL1D
#   Applying log10 transform to column: TotalTrxAmountL7D
#   Log10 transformed column: TotalTrxAmountL7D
#   Applying log10 transform to column: TotalTrxAmount15Mi
#   Log10 transformed column: TotalTrxAmount15Mi
#   Applying log10 transform to column: CreditLimit
#   Log10 transformed column: CreditLimit
#   Applying log10 transform to column: CashCreditLimit
#   Log10 transformed column: CashCreditLimit
#   Applying log10 transform to column: TotalTrxAmount10Mi
#   Log10 transformed column: TotalTrxAmount10Mi
#   Applying log10 transform to column: TotalTrxAmountL5min
#   Log10 transformed column: TotalTrxAmountL5min
#   Applying log10 transform to column: TotalTrxAmountContactless
#   Log10 transformed column: TotalTrxAmountContactless
#   Applying log10 transform to column: IsHighRiskCountryThresholdAmt
#   Log10 transformed column: IsHighRiskCountryThresholdAmt
#   Applying log10 transform to column: IsHighRiskCurrencyThresholdAmt
#   Log10 transformed column: IsHighRiskCurrencyThresholdAmt
#   Applying log10 transform to column: TotalTrxAmount30Mi
#   Log10 transformed column: TotalTrxAmount30Mi
# Core numeric and boolean preprocessing complete.
# Fitting CategoryManager...
#   Fitted categories for column 'MCC Category': ['AIRLINES, AIR CARRIERS', 'ASSOCIATIONS/ORGANIZATIONS', 'BUSINESS/PROFESSIONAL/MISCELLANEOUS SERVICES', 'CAR RENTAL AGENCIES', 'CLOTHING/SHOES/ACCESSORIES/UNIFORMS/RETAIL STORES/BUYING AND SELLING SERVICES', 'EDUCATIONAL SERVICES', 'ELECTRONIC AND TECHNICAL SERVICES', 'ENTERTAINMENT/THEATER/DANCE STUDIOS', 'FINANCIAL SERVICES', 'FURNISHINGS/APPLIANCES/MAINTENANCE/HOME', 'GROCERY STORES/PHARMACIES/FOOD SERVICES/RESTAURANTS', 'HEALTHCARE/CHILD SERVICES', 'LODGING — HOTELS, MOTELS, RESORTS', 'OTHER', 'PERSONAL SERVICES', 'TRAVEL/TRANSPORTATION/GAS AND FUEL SERVICES', '__missing__']
#   Fitted categories for column 'Country Code': ['100', '116', '12', '124', '144', '152', '156', '158', '170', '191', '196', '203', '208', '233', '242', '246', '250', '268', '276', '280', '292', '300', '308', '32', '328', '344', '348', '352', '356', '36', '360', '372', '376', '380', '392', '398', '40', '400', '404', '410', '414', '417', '418', '428', '44', '440', '442', '446', '458', '462', '470', '48', '484', '498', '50', '504', '51', '512', '524', '528', '540', '554', '558', '56', '578', '586', '598', '600', '604', '608', '616', '620', '634', '643', '682', '702', '704', '705', '710', '724', '744', '752', '756', '76', '764', '780', '784', '792', '804', '807', '818', '826', '840', '858', '860', '901', '933', '941', '944', '946', '949', '952', '96', '977', '978', '980', '981', '985', '986', '__missing__']
#   Fitted categories for column 'Cat Card Acceptor Name': ['DIGITAL PRODUCTS', 'E-LEARNING', 'ECOMMERCE', 'FINANCE', 'FOOD & BEVERAGE', 'GAMING', 'GOVERNMENT & PUBLIC SERVICES', 'HEALTH & WELLNESS', 'HOTELS & RESORTS', 'MEDICAL & INSURANCE', 'ONLINE SUBSCRIPTION', 'OTHER', 'PETROL & GAS STATIONS', 'RETAIL - ELECTRONICS', 'RETAIL - FURNITURE', 'RETAIL - OTHERS', 'SOCIAL MEDIA', 'TECHNOLOGY', 'TICKETS', 'TRANSPORTATION', 'TRAVEL', 'UTILITIES', '__missing__']
#   Fitted categories for column 'Currency Code': ['116', '124', '156', '203', '208', '32', '344', '348', '352', '356', '36', '360', '376', '392', '410', '446', '458', '462', '484', '50', '504', '512', '554', '578', '598', '600', '608', '634', '682', '702', '704', '752', '756', '764', '784', '818', '826', '840', '858', '901', '949', '953', '96', '975', '978', '986', '__missing__']
#   Fitted categories for column 'AccountStatus': ['1', '2', '6', '8', '__missing__']
#   Fitted categories for column 'CardStatus': ['1', '2', '4', '8', '__missing__']
#   Fitted categories for column 'CardProduct': ['1', '10', '100', '110', '12', '123', '20', '200', '201', '21', '210', '217', '22', '223', '300', '301', '310', '351', '400', '401', '410', '412', '414', '417', '424', '434', '440', '500', '501', '502', '503', '504', '505', '510', '517', '523', '528', '530', '531', '600', '601', '603', '604', '605', '606', '610', '616', '617', '622', '630', '631', '634', '636', '637', '640', '688', '700', '701', '702', '703', '710', '8', '888', '900', '901', '__missing__']
#   Fitted categories for column 'CustomerSex': ['0', '1', '2', '__missing__']
#   Fitted categories for column 'Currency': ['AED', 'ARS', 'AUD', 'BDT', 'BGN', 'BND', 'BRL', 'CAD', 'CHF', 'CNY', 'CZK', 'DKK', 'EGP', 'EUR', 'GBP', 'HKD', 'HUF', 'IDR', 'ILS', 'INR', 'ISK', 'JPY', 'KHR', 'KRW', 'MAD', 'MOP', 'MVR', 'MXN', 'MYR', 'NOK', 'NZD', 'OMR', 'PGK', 'PHP', 'PYG', 'QAR', 'SAR', 'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'UYU', 'VND', 'XPF', '__missing__']
#   Fitted categories for column 'POSMode': ['0', '1', '2', '5', '6', '7', '9', 'A ', '__missing__']
#   Fitted categories for column 'PINEntryCapability': ['0', '1', '2', '4', '5', '6', '8', '9', 'A', 'C', '__missing__']
#   Fitted categories for column 'TransactionType': ['0', '1', '2', '20', '31', '50', '53', '80', '81', '__missing__']
#   Fitted categories for column 'SourceChannel': ['ATM', 'POS', '__missing__']
#   Fitted categories for column 'VCardDataInputCapability': ['0', '1', '2', '5', '6', '7', '8', 'A', '__missing__']
#   Fitted categories for column 'CustomerNationality': ['AUSTRALIA', 'AUSTRIA', 'CANADA', 'ENGLAND', 'FILIPHINES', 'FRANCE', 'GERMANY', 'GREECE', 'INDIA', 'INDONESIA', 'INGGRIS', 'ITALIA', 'JAPAN', 'KOREA SELATAN', 'MALAYSIA', 'NETHERLANDS', 'NEW ZEALAND', 'PAKISTAN', 'PHILIPPINES', 'SENEGAL', 'SERBIA', 'SINGAPORE', 'SPAIN', 'SPANYOL', 'SWEDEN', 'UKRAINE', 'UNITED STATES', '__missing__']
# CategoryManager fitting complete.
# Transforming data using CategoryManager...
#   Transformed column 'MCC Category' to numerical codes.
#   Transformed column 'Country Code' to numerical codes.
#   Transformed column 'Cat Card Acceptor Name' to numerical codes.
#   Transformed column 'Currency Code' to numerical codes.
#   Transformed column 'AccountStatus' to numerical codes.
#   Transformed column 'CardStatus' to numerical codes.
#   Transformed column 'CardProduct' to numerical codes.
#   Transformed column 'CustomerSex' to numerical codes.
#   Transformed column 'Currency' to numerical codes.
#   Transformed column 'POSMode' to numerical codes.
#   Transformed column 'PINEntryCapability' to numerical codes.
#   Transformed column 'TransactionType' to numerical codes.
#   Transformed column 'SourceChannel' to numerical codes.
#   Transformed column 'VCardDataInputCapability' to numerical codes.
#   Transformed column 'CustomerNationality' to numerical codes.
# CategoryManager transformation complete.
# Identified numerical columns for imputation: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_ ...
# Identified categorical columns (encoded): ['MCC Category', 'Country Code', 'Cat Card Acceptor Name', 'Currency Code', 'AccountStatus', 'CardStatus', 'CardProduct', 'CustomerSex', 'Currency', 'POSMode', 'PINEntryCapability', 'TransactionType', 'SourceChannel', 'VCardDataInputCapability', 'CustomerNationality']
# Fitting NumericalImputer...
#   Fitted median for column 'time_diff': 233.25
#   Fitted median for column 'TxnCount_L15M': 0.0
#   Fitted median for column 'TxnCount_L1H': 0.0
#   Fitted median for column 'TxnCount_L1D': 1.0
#   Fitted median for column 'TxnCount_L7D': 7.0
#   Fitted median for column 'TxnCount_L14D': 13.0
#   Fitted median for column 'TxnCount_L30D': 23.0
#   Fitted median for column 'TxnCount_L90D': 43.0
#   Fitted median for column 'TxnCount_to_MCC_L15M': 0.0
#   Fitted median for column 'TxnCount_to_MCC_L1H': 0.0
#   Fitted median for column 'TxnCount_to_MCC_L1D': 0.0
#   Fitted median for column 'TxnCount_to_MCC_L7D': 2.0
#   Fitted median for column 'TxnCount_to_MCC_L14D': 3.0
#   Fitted median for column 'TxnCount_to_MCC_L30D': 4.0
#   Fitted median for column 'TxnCount_to_MCC_L90D': 8.0
#   Fitted median for column 'TxnCount_to_MCC_details_L15M': 0.0
#   Fitted median for column 'TxnCount_to_MCC_details_L1H': 0.0
#   Fitted median for column 'TxnCount_to_MCC_details_L1D': 0.0
#   Fitted median for column 'TxnCount_to_MCC_details_L7D': 2.0
#   Fitted median for column 'TxnCount_to_MCC_details_L14D': 3.0
#   Fitted median for column 'TxnCount_to_MCC_details_L30D': 5.0
#   Fitted median for column 'TxnCount_to_MCC_details_L90D': 8.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L15M': 0.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L1H': 0.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L1D': 1.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L7D': 4.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L14D': 6.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L30D': 11.0
#   Fitted median for column 'TxnCount_to_MCC_catcode_L90D': 19.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L15M': 0.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L1H': 0.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L1D': 1.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L7D': 3.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L14D': 5.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L30D': 8.0
#   Fitted median for column 'TxnCount_to_MCC_cat_L90D': 14.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L15M': 0.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L1H': 0.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L1D': 1.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L7D': 3.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L14D': 5.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L30D': 9.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_cat_L90D': 16.0
#   Fitted median for column 'TxnCount_to_countryCode_L15M': 0.0
#   Fitted median for column 'TxnCount_to_countryCode_L1H': 0.0
#   Fitted median for column 'TxnCount_to_countryCode_L1D': 1.0
#   Fitted median for column 'TxnCount_to_countryCode_L7D': 6.0
#   Fitted median for column 'TxnCount_to_countryCode_L14D': 10.0
#   Fitted median for column 'TxnCount_to_countryCode_L30D': 18.0
#   Fitted median for column 'TxnCount_to_countryCode_L90D': 33.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L15M': 0.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L1H': 0.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L1D': 1.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L7D': 5.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L14D': 8.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L30D': 13.0
#   Fitted median for column 'TxnCount_to_cardAcceptor_country_L90D': 23.0
#   Fitted median for column 'Avg_Amt_L15M': 0.0
#   Fitted median for column 'Avg_Amt_L1H': 0.0
#   Fitted median for column 'Avg_Amt_L1D': 4.778158664703369
#   Fitted median for column 'Avg_Amt_L7D': 5.2834062576293945
#   Fitted median for column 'Avg_Amt_L14D': 5.378139972686768
#   Fitted median for column 'Avg_Amt_L30D': 5.471024513244629
#   Fitted median for column 'Avg_Amt_L90D': 5.551766872406006
#   Fitted median for column 'Max_Amt_L15M': 0.0
#   Fitted median for column 'Max_Amt_L1H': 0.0
#   Fitted median for column 'Max_Amt_L1D': 4.95231294631958
#   Fitted median for column 'Max_Amt_L7D': 5.708972930908203
#   Fitted median for column 'Max_Amt_L14D': 5.931661605834961
#   Fitted median for column 'Max_Amt_L30D': 6.175801753997803
#   Fitted median for column 'Max_Amt_L90D': 6.365113735198975
#   Fitted median for column 'Sum_Amt_L14D': 6.514176368713379
#   Fitted median for column 'Sum_Amt_L30D': 6.83538293838501
#   Fitted median for column 'Sum_Amt_L90D': 7.178675174713135
#   Fitted median for column 'Avg_Amt_to_MCC_L15M': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_L1H': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_L1D': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_L7D': 4.673951148986816
#   Fitted median for column 'Avg_Amt_to_MCC_L14D': 4.821440696716309
#   Fitted median for column 'Avg_Amt_to_MCC_L30D': 4.953762054443359
#   Fitted median for column 'Avg_Amt_to_MCC_L90D': 5.061819553375244
#   Fitted median for column 'Max_Amt_to_MCC_L15M': 0.0
#   Fitted median for column 'Max_Amt_to_MCC_L1H': 0.0
#   Fitted median for column 'Max_Amt_to_MCC_L1D': 0.0
#   Fitted median for column 'Max_Amt_to_MCC_L7D': 4.926347732543945
#   Fitted median for column 'Max_Amt_to_MCC_L14D': 5.120449066162109
#   Fitted median for column 'Max_Amt_to_MCC_L30D': 5.309632301330566
#   Fitted median for column 'Max_Amt_to_MCC_L90D': 5.492720127105713
#   Fitted median for column 'Sum_Amt_to_MCC_L15M': 0.0
#   Fitted median for column 'Sum_Amt_to_MCC_L1H': 0.0
#   Fitted median for column 'Sum_Amt_to_MCC_L1D': 0.0
#   Fitted median for column 'Sum_Amt_to_MCC_L7D': 5.2986249923706055
#   Fitted median for column 'Sum_Amt_to_MCC_L14D': 5.608038902282715
#   Fitted median for column 'Sum_Amt_to_MCC_L30D': 5.928460121154785
#   Fitted median for column 'Sum_Amt_to_MCC_L90D': 6.2379150390625
#   Fitted median for column 'Avg_Amt_to_MCC_cat_L15M': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_cat_L1H': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_cat_L1D': 0.0
#   Fitted median for column 'Avg_Amt_to_MCC_cat_L7D': 4.848049163818359
#   Fitted median for column 'Avg_Amt_to_MCC_cat_L14D': 4.971617698669434
# ...
#   Imputed column 'Max_Amt_to_MCC_L14D' with value: 5.120449066162109
#   Imputed column 'Max_Amt_to_MCC_L30D' with value: 5.309632301330566
#   Imputed column 'Max_Amt_to_MCC_L90D' with value: 5.492720127105713
#   Imputed column 'Sum_Amt_to_MCC_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L1D' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L7D' with value: 5.2986249923706055
#   Imputed column 'Sum_Amt_to_MCC_L14D' with value: 5.608038902282715
#   Imputed column 'Sum_Amt_to_MCC_L30D' with value: 5.928460121154785
#   Imputed column 'Sum_Amt_to_MCC_L90D' with value: 6.2379150390625
#   Imputed column 'Avg_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L7D' with value: 4.848049163818359
#   Imputed column 'Avg_Amt_to_MCC_cat_L14D' with value: 4.971617698669434
#   Imputed column 'Avg_Amt_to_MCC_cat_L30D' with value: 5.092095375061035
#   Imputed column 'Avg_Amt_to_MCC_cat_L90D' with value: 5.185332775115967
#   Imputed column 'Max_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L7D' with value: 5.112273216247559
#   Imputed column 'Max_Amt_to_MCC_cat_L14D' with value: 5.306427001953125
#   Imputed column 'Max_Amt_to_MCC_cat_L30D' with value: 5.52058219909668
#   Imputed column 'Max_Amt_to_MCC_cat_L90D' with value: 5.698970794677734
#   Imputed column 'Sum_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L7D' with value: 5.518186092376709
#   Imputed column 'Sum_Amt_to_MCC_cat_L14D' with value: 5.818617820739746
#   Imputed column 'Sum_Amt_to_MCC_cat_L30D' with value: 6.131781578063965
#   Imputed column 'Sum_Amt_to_MCC_cat_L90D' with value: 6.451018810272217
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L1D' with value: 4.0000433921813965
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L7D' with value: 4.916314125061035
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L14D' with value: 5.021943092346191
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L30D' with value: 5.158873081207275
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L90D' with value: 5.266674995422363
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L1D' with value: 4.0414323806762695
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L7D' with value: 5.218512058258057
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L14D' with value: 5.387633800506592
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L30D' with value: 5.572087287902832
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L90D' with value: 5.755875587463379
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L1D' with value: 4.176120281219482
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L7D' with value: 5.681061267852783
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L14D' with value: 5.966826915740967
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L30D' with value: 6.277665138244629
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L90D' with value: 6.608013153076172
#   Imputed column 'Avg_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_countryCode_L1D' with value: 4.702223777770996
#   Imputed column 'Avg_Amt_to_countryCode_L7D' with value: 5.222719192504883
#   Imputed column 'Avg_Amt_to_countryCode_L14D' with value: 5.312819480895996
#   Imputed column 'Avg_Amt_to_countryCode_L30D' with value: 5.408265113830566
#   Imputed column 'Avg_Amt_to_countryCode_L90D' with value: 5.485235691070557
#   Imputed column 'Max_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_countryCode_L1D' with value: 4.866883754730225
#   Imputed column 'Max_Amt_to_countryCode_L7D' with value: 5.636889934539795
#   Imputed column 'Max_Amt_to_countryCode_L14D' with value: 5.829562664031982
#   Imputed column 'Max_Amt_to_countryCode_L30D' with value: 6.052155494689941
#   Imputed column 'Max_Amt_to_countryCode_L90D' with value: 6.278753757476807
#   Imputed column 'Sum_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_countryCode_L1D' with value: 5.063224792480469
#   Imputed column 'Sum_Amt_to_countryCode_L7D' with value: 6.122707366943359
#   Imputed column 'Sum_Amt_to_countryCode_L14D' with value: 6.41076135635376
#   Imputed column 'Sum_Amt_to_countryCode_L30D' with value: 6.720290184020996
#   Imputed column 'Sum_Amt_to_countryCode_L90D' with value: 7.05148458480835
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L1D' with value: 4.414989948272705
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L7D' with value: 5.053033351898193
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L14D' with value: 5.156097888946533
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L30D' with value: 5.2614946365356445
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L90D' with value: 5.338566780090332
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L1D' with value: 4.544092655181885
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L7D' with value: 5.444808006286621
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L14D' with value: 5.6275434494018555
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L30D' with value: 5.838478088378906
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L90D' with value: 6.032883167266846
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L1D' with value: 4.731596946716309
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L7D' with value: 5.920513153076172
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L14D' with value: 6.20412015914917
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L30D' with value: 6.5125885009765625
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L90D' with value: 6.836496353149414
#   Imputed column 'CntUnique_MCC_by_CardNo_L15M' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L1H' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L1D' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L7D' with value: 3.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L14D' with value: 4.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L30D' with value: 5.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L90D' with value: 7.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L15M' with value: 3.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L1H' with value: 10.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L1D' with value: 89.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L7D' with value: 361.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L14D' with value: 532.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L30D' with value: 743.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L90D' with value: 1065.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L15M' with value: 7.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L1H' with value: 25.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L1D' with value: 216.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L7D' with value: 681.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L14D' with value: 996.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L30D' with value: 1397.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L90D' with value: 1871.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L15M' with value: 38.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L1H' with value: 134.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L1D' with value: 928.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L7D' with value: 2291.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L14D' with value: 2857.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L30D' with value: 3396.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L90D' with value: 3949.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L15M' with value: 19.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L1H' with value: 65.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L1D' with value: 492.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L7D' with value: 1280.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L14D' with value: 1707.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L30D' with value: 2129.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L90D' with value: 2618.0
#   Imputed column 'Transaction Amount' with value: 5.159870624542236
#   Imputed column 'CustomerAge' with value: 41.0
#   Imputed column 'AgeOfOpenAcctTxn' with value: 2629.0
#   Imputed column 'AgeOfActiveCardTxn' with value: 1126.0
#   Imputed column 'TotalTrxAmountL1D' with value: 5.503425598144531
#   Imputed column 'TotalTrxAmountL7D' with value: 6.190331935882568
#   Imputed column 'TotalTrxAmount15Mi' with value: 5.1020941734313965
#   Imputed column 'IsBlacklistCust' with value: 0.0
#   Imputed column 'NumOfTrxL1D' with value: 2.0
#   Imputed column 'NumOfTrxL7D' with value: 8.0
#   Imputed column 'IsHighRiskCountry' with value: 0.0
#   Imputed column 'IsBlacklistMerchant' with value: 0.0
#   Imputed column 'IsWatchListMerchant' with value: 0.0
#   Imputed column 'IsHighRiskMCC' with value: 0.0
#   Imputed column 'CreditLimit' with value: 7.6901960372924805
#   Imputed column 'CashCreditLimit' with value: 7.292255878448486
#   Imputed column 'IsBlacklistCardNo' with value: 0.0
#   Imputed column 'IsValidCard' with value: 1.0
#   Imputed column 'Is3DSecure' with value: 0.0
#   Imputed column 'IsWhiteListMerchant' with value: 0.0
#   Imputed column 'IsBDIEmail' with value: 0.0
#   Imputed column 'IsWhiteListCardNo' with value: 0.0
#   Imputed column 'TotalTrxAmount10Mi' with value: 5.086719036102295
#   Imputed column 'TotalTrxAmountL5min' with value: 5.073721885681152
#   Imputed column 'TotalTrxAmountContactless' with value: 0.0
#   Imputed column 'IsWhitelistCardNoOpen' with value: 0.0
#   Imputed column 'IsWatchlistCardNo' with value: 0.0
#   Imputed column 'IsBlackListTID' with value: 0.0
#   Imputed column 'IsFirstTrx3DS' with value: 0.0
#   Imputed column 'IsHighRiskCountryThresholdAmt' with value: 0.0
#   Imputed column 'IsHighRiskCurrency' with value: 0.0
#   Imputed column 'IsHighRiskCurrencyThresholdAmt' with value: 0.0
#   Imputed column 'IsWhitelistCardNoPrevilage' with value: 0.0
#   Imputed column 'IsWhiteListTID' with value: 0.0
#   Imputed column 'IsWatchListTID' with value: 0.0
#   Imputed column 'TotalTrxAmount30Mi' with value: 4.8998260498046875
#   Imputed column 'IsBucket1WatchListCardNo' with value: 0.0
#   Imputed column 'IsBucket1BlacklistCardNo' with value: 0.0
#   Imputed column 'IsBucket1WhiteListCardNo' with value: 0.0
#   Imputed column 'IsBucket2WhiteListMerchant' with value: 0.0
#   Imputed column 'IsBucket2WatchListMerchant' with value: 0.0
#   Imputed column 'IsBucket2BlacklistMerchant' with value: 0.0
# NumericalImputer transformation complete.
# Final feature columns: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_Amt_to_countryCode_L15 ...
# Data preparation complete.

# %%
# split data
X_train, X_test, y_train, y_test = pipeline.split_data(X, y, test_size=0.3)
# Out:
# Splitting data into train and test sets...
# Data splitting complete.

# %%
len(X.columns)
# Out:
# 271

# %% [markdown]
# ## Check Missing Value

# %%
from src.utils import get_features_by_missing_pct

# %%
selected_cols, summary_df = get_features_by_missing_pct(
    df_splits["df_train"], 0.99, ["Transaction Datetime", "Confirmed"]
)

# %%
summary_df[~summary_df.feature.isin(["Transaction Datetime", "Confirmed"])].reset_index(
    drop=True
)
# Out:
#                            feature  missing_pct
# 0                     Avg_Amt_L15M     0.003100
# 1              Avg_Amt_to_MCC_L30D     0.003100
# 2                     Max_Amt_L15M     0.003100
# 3              Max_Amt_to_MCC_L15M     0.003100
# 4              Max_Amt_to_MCC_L30D     0.003100
# 5      Max_Amt_to_countryCode_L15M     0.003100
# 6              Sum_Amt_to_MCC_L15M     0.003100
# 7              Sum_Amt_to_MCC_L30D     0.003100
# 8      Sum_Amt_to_countryCode_L15M     0.003100
# 9                    TxnCount_L30D     0.003100
# 10    TxnCount_to_countryCode_L30D     0.003115
# 11                       time_diff     0.030977
# 12                      CardStatus     0.161231
# 13                     CustomerSex     0.168964
# 14                    MCC Category     0.095632
# 15                         POSMode     0.091058
# 16              TotalTrxAmount10Mi     0.134614
# 17              TotalTrxAmount15Mi     0.134600
# 18              TotalTrxAmount30Mi     0.254264
# 19               TotalTrxAmountL1D     0.133974
# 20             TotalTrxAmountL5min     0.134626
# 21              Transaction Amount     0.008015
# 22  ratio_max_amt_to_mcc_L30D_L15M     0.000000
# 23  ratio_sum_amt_to_mcc_L30D_L15M     0.000000
# 24          RatioTrxAmountL1DL5min     0.000000
# 25         RatioTrxAmountL1DL15min     0.000000
# 26         RatioTrxAmountL1DL10min     0.000000
# 27         RatioTrxAmountL1DL30min     0.000000
# 28              CardProductGrouped     0.000000
# 29               CurrencyCodeGroup     0.000000

# %% [markdown]
# # Over-Sampling

# %%
from src.imbalance_learn import ImbalancedSampler

# %%
# OverSampling
ros_sampler = ImbalancedSampler(
    algorithm="RandomOverSampler",
    sampler_type="upsample",
    target_ratio=0.2,  # 7%
    random_state=1234,
)

X_train_ros, y_train_ros = ros_sampler.fit_resample(X_train, y_train)
# Out:
# Original dataset shape: Counter({False: 831875, True: 6222})
# Resampled dataset shape using RandomOverSampler: Counter({False: 831875, True: 166375})

# %% [markdown]
# # Model Fit

# %%
# build and trai0_n
pipeline.build_pipeline()
pipeline.train(X_train_ros, y_train_ros, show_training_log=False)
# Out:
# Building pipeline...
# Pipeline built.
# Training model...
# C:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [21:19:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Model training complete.

# %%
# Evaluate
test_results = pipeline.evaluate(X_test, y_test)
# Out:
# Evaluating model...
# Accuracy: 0.9978
# AUC: 0.9968
# PR AUC: 0.9309
# Precision: 0.8292
# Recall: 0.8939
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00    356518
#         True       0.83      0.89      0.86      2667
#
#     accuracy                           1.00    359185
#    macro avg       0.91      0.95      0.93    359185
# weighted avg       1.00      1.00      1.00    359185

# %% [markdown]
# # Eval Model

# %%
from src.utils import plot_confusion_matrix

# %%
y_prob = pipeline.pipeline.predict_proba(X_test)[:, 1]
plot_confusion_matrix(y_test, y_prob, 0.5)
# Out:
# Recall/True Positive Rate: The model got 89.39% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 82.92% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.14% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# # Calibrated CV

# %%
from sklearn.calibration import CalibratedClassifierCV

# %%
base_xgb = pipeline.get_model()
# Out:
# Returning trained model...

# %%
calibrated_xgb = CalibratedClassifierCV(
    estimator=base_xgb, method="sigmoid", cv="prefit"
)

# %%
calibrated_xgb.fit(X_train_ros, y_train_ros)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=None,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None,
#                                                feature_weights=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=None, max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=None, max_leaves=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=1000, n_jobs=-1,
#                                                num_parallel_tree=None, ...))

# %%
y_prob_cal = calibrated_xgb.predict_proba(X_test)[:, 1]
plot_confusion_matrix(y_test, y_prob_cal, 0.5)
# Out:
# Recall/True Positive Rate: The model got 89.31% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 83.34% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.13% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
plot_confusion_matrix(y_test, y_prob_cal, 0.01)
# Out:
# Recall/True Positive Rate: The model got 90.55% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 80.82% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.16% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# # Back-Testing with OOS Data

# %%
df_credit_mix = pd.read_parquet("data/base/df_credit_clean_dec24_may25.parquet")
trx_id_list = list(
    df_credit_mix[df_credit_mix.Confirmed.isin([0, 1])]["Transaction Serial No"]
)
df_oos_new = df_splits["df_test"][df_splits["df_test"].index.isin(trx_id_list)]

# %%
X_oos, y_oos = pipeline.prepare_data(
    df=df_splits["df_test"],
    # df=df_oos_new,
    target_column=target_col,
    exclude_columns=["Transaction Datetime"],
    is_apply_one_hot=False,
    is_apply_log=True,
    is_impute_median=True,
    is_training=False,
)
# Out:
# Preparing data (is_training=False)...
# Starting core numeric and boolean preprocessing...
#   Float columns to downcast: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_Amt_to_countryCo ...
#   Downcasted column: time_diff
#   Downcasted column: TxnCount_L15M
#   Downcasted column: TxnCount_L1H
#   Downcasted column: TxnCount_L1D
#   Downcasted column: TxnCount_L7D
#   Downcasted column: TxnCount_L14D
#   Downcasted column: TxnCount_L30D
#   Downcasted column: TxnCount_L90D
#   Downcasted column: TxnCount_to_MCC_L15M
#   Downcasted column: TxnCount_to_MCC_L1H
#   Downcasted column: TxnCount_to_MCC_L1D
#   Downcasted column: TxnCount_to_MCC_L7D
#   Downcasted column: TxnCount_to_MCC_L14D
#   Downcasted column: TxnCount_to_MCC_L30D
#   Downcasted column: TxnCount_to_MCC_L90D
#   Downcasted column: TxnCount_to_MCC_details_L15M
#   Downcasted column: TxnCount_to_MCC_details_L1H
#   Downcasted column: TxnCount_to_MCC_details_L1D
#   Downcasted column: TxnCount_to_MCC_details_L7D
#   Downcasted column: TxnCount_to_MCC_details_L14D
#   Downcasted column: TxnCount_to_MCC_details_L30D
#   Downcasted column: TxnCount_to_MCC_details_L90D
#   Downcasted column: TxnCount_to_MCC_catcode_L15M
#   Downcasted column: TxnCount_to_MCC_catcode_L1H
#   Downcasted column: TxnCount_to_MCC_catcode_L1D
#   Downcasted column: TxnCount_to_MCC_catcode_L7D
#   Downcasted column: TxnCount_to_MCC_catcode_L14D
#   Downcasted column: TxnCount_to_MCC_catcode_L30D
#   Downcasted column: TxnCount_to_MCC_catcode_L90D
#   Downcasted column: TxnCount_to_MCC_cat_L15M
#   Downcasted column: TxnCount_to_MCC_cat_L1H
#   Downcasted column: TxnCount_to_MCC_cat_L1D
#   Downcasted column: TxnCount_to_MCC_cat_L7D
#   Downcasted column: TxnCount_to_MCC_cat_L14D
#   Downcasted column: TxnCount_to_MCC_cat_L30D
#   Downcasted column: TxnCount_to_MCC_cat_L90D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L15M
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L1H
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L1D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L7D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L14D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L30D
#   Downcasted column: TxnCount_to_cardAcceptor_cat_L90D
#   Downcasted column: TxnCount_to_countryCode_L15M
#   Downcasted column: TxnCount_to_countryCode_L1H
#   Downcasted column: TxnCount_to_countryCode_L1D
#   Downcasted column: TxnCount_to_countryCode_L7D
#   Downcasted column: TxnCount_to_countryCode_L14D
#   Downcasted column: TxnCount_to_countryCode_L30D
#   Downcasted column: TxnCount_to_countryCode_L90D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L15M
#   Downcasted column: TxnCount_to_cardAcceptor_country_L1H
#   Downcasted column: TxnCount_to_cardAcceptor_country_L1D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L7D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L14D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L30D
#   Downcasted column: TxnCount_to_cardAcceptor_country_L90D
#   Downcasted column: Avg_Amt_L15M
#   Downcasted column: Avg_Amt_L1H
#   Downcasted column: Avg_Amt_L1D
#   Downcasted column: Avg_Amt_L7D
#   Downcasted column: Avg_Amt_L14D
#   Downcasted column: Avg_Amt_L30D
#   Downcasted column: Avg_Amt_L90D
#   Downcasted column: Max_Amt_L15M
#   Downcasted column: Max_Amt_L1H
#   Downcasted column: Max_Amt_L1D
#   Downcasted column: Max_Amt_L7D
#   Downcasted column: Max_Amt_L14D
#   Downcasted column: Max_Amt_L30D
#   Downcasted column: Max_Amt_L90D
#   Downcasted column: Sum_Amt_L14D
#   Downcasted column: Sum_Amt_L30D
#   Downcasted column: Sum_Amt_L90D
#   Downcasted column: Avg_Amt_to_MCC_L15M
#   Downcasted column: Avg_Amt_to_MCC_L1H
#   Downcasted column: Avg_Amt_to_MCC_L1D
#   Downcasted column: Avg_Amt_to_MCC_L7D
#   Downcasted column: Avg_Amt_to_MCC_L14D
#   Downcasted column: Avg_Amt_to_MCC_L30D
#   Downcasted column: Avg_Amt_to_MCC_L90D
#   Downcasted column: Max_Amt_to_MCC_L15M
#   Downcasted column: Max_Amt_to_MCC_L1H
#   Downcasted column: Max_Amt_to_MCC_L1D
#   Downcasted column: Max_Amt_to_MCC_L7D
#   Downcasted column: Max_Amt_to_MCC_L14D
#   Downcasted column: Max_Amt_to_MCC_L30D
#   Downcasted column: Max_Amt_to_MCC_L90D
#   Downcasted column: Sum_Amt_to_MCC_L15M
#   Downcasted column: Sum_Amt_to_MCC_L1H
#   Downcasted column: Sum_Amt_to_MCC_L1D
#   Downcasted column: Sum_Amt_to_MCC_L7D
#   Downcasted column: Sum_Amt_to_MCC_L14D
#   Downcasted column: Sum_Amt_to_MCC_L30D
#   Downcasted column: Sum_Amt_to_MCC_L90D
#   Downcasted column: Avg_Amt_to_MCC_cat_L15M
#   Downcasted column: Avg_Amt_to_MCC_cat_L1H
#   Downcasted column: Avg_Amt_to_MCC_cat_L1D
#   Downcasted column: Avg_Amt_to_MCC_cat_L7D
#   Downcasted column: Avg_Amt_to_MCC_cat_L14D
#   Downcasted column: Avg_Amt_to_MCC_cat_L30D
#   Downcasted column: Avg_Amt_to_MCC_cat_L90D
#   Downcasted column: Max_Amt_to_MCC_cat_L15M
#   Downcasted column: Max_Amt_to_MCC_cat_L1H
#   Downcasted column: Max_Amt_to_MCC_cat_L1D
#   Downcasted column: Max_Amt_to_MCC_cat_L7D
#   Downcasted column: Max_Amt_to_MCC_cat_L14D
#   Downcasted column: Max_Amt_to_MCC_cat_L30D
#   Downcasted column: Max_Amt_to_MCC_cat_L90D
#   Downcasted column: Sum_Amt_to_MCC_cat_L15M
#   Downcasted column: Sum_Amt_to_MCC_cat_L1H
#   Downcasted column: Sum_Amt_to_MCC_cat_L1D
#   Downcasted column: Sum_Amt_to_MCC_cat_L7D
#   Downcasted column: Sum_Amt_to_MCC_cat_L14D
#   Downcasted column: Sum_Amt_to_MCC_cat_L30D
#   Downcasted column: Sum_Amt_to_MCC_cat_L90D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Max_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Downcasted column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Downcasted column: Avg_Amt_to_countryCode_L15M
#   Downcasted column: Avg_Amt_to_countryCode_L1H
#   Downcasted column: Avg_Amt_to_countryCode_L1D
#   Downcasted column: Avg_Amt_to_countryCode_L7D
#   Downcasted column: Avg_Amt_to_countryCode_L14D
#   Downcasted column: Avg_Amt_to_countryCode_L30D
#   Downcasted column: Avg_Amt_to_countryCode_L90D
#   Downcasted column: Max_Amt_to_countryCode_L15M
#   Downcasted column: Max_Amt_to_countryCode_L1H
#   Downcasted column: Max_Amt_to_countryCode_L1D
#   Downcasted column: Max_Amt_to_countryCode_L7D
#   Downcasted column: Max_Amt_to_countryCode_L14D
#   Downcasted column: Max_Amt_to_countryCode_L30D
#   Downcasted column: Max_Amt_to_countryCode_L90D
#   Downcasted column: Sum_Amt_to_countryCode_L15M
#   Downcasted column: Sum_Amt_to_countryCode_L1H
#   Downcasted column: Sum_Amt_to_countryCode_L1D
#   Downcasted column: Sum_Amt_to_countryCode_L7D
#   Downcasted column: Sum_Amt_to_countryCode_L14D
#   Downcasted column: Sum_Amt_to_countryCode_L30D
#   Downcasted column: Sum_Amt_to_countryCode_L90D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Avg_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Max_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L15M
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L1H
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L1D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L7D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L14D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L30D
#   Downcasted column: Sum_Amt_to_cardAcceptor_country_L90D
#   Downcasted column: CntUnique_MCC_by_CardNo_L15M
#   Downcasted column: CntUnique_MCC_by_CardNo_L1H
#   Downcasted column: CntUnique_MCC_by_CardNo_L1D
#   Downcasted column: CntUnique_MCC_by_CardNo_L7D
#   Downcasted column: CntUnique_MCC_by_CardNo_L14D
#   Downcasted column: CntUnique_MCC_by_CardNo_L30D
#   Downcasted column: CntUnique_MCC_by_CardNo_L90D
#   Downcasted column: CntUnique_CardNo_by_MCC_L15M
#   Downcasted column: CntUnique_CardNo_by_MCC_L1H
#   Downcasted column: CntUnique_CardNo_by_MCC_L1D
#   Downcasted column: CntUnique_CardNo_by_MCC_L7D
#   Downcasted column: CntUnique_CardNo_by_MCC_L14D
#   Downcasted column: CntUnique_CardNo_by_MCC_L30D
#   Downcasted column: CntUnique_CardNo_by_MCC_L90D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L15M
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L1H
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L1D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L7D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L14D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L30D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_cat_L90D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L15M
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L1H
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L1D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L7D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L14D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L30D
#   Downcasted column: CntUnique_CardNo_by_currencyCode_L90D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L15M
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L1H
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L1D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L7D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L14D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L30D
#   Downcasted column: CntUnique_CardNo_by_cardAcceptor_country_L90D
#   Downcasted column: Transaction Amount
#   Downcasted column: CustomerAge
#   Downcasted column: AgeOfOpenAcctTxn
#   Downcasted column: AgeOfActiveCardTxn
#   Downcasted column: TotalTrxAmountL1D
#   Downcasted column: TotalTrxAmountL7D
#   Downcasted column: TotalTrxAmount15Mi
#   Downcasted column: NumOfTrxL1D
#   Downcasted column: NumOfTrxL7D
#   Downcasted column: CreditLimit
#   Downcasted column: CashCreditLimit
#   Downcasted column: TotalTrxAmount10Mi
#   Downcasted column: TotalTrxAmountL5min
#   Downcasted column: TotalTrxAmountContactless
#   Downcasted column: TotalTrxAmount30Mi
#   Mapping Y/N to 1/0 in column: IsBlacklistCust
#   Mapping Y/N to 1/0 in column: IsHighRiskCountry
#   Mapping Y/N to 1/0 in column: IsBlacklistMerchant
#   Mapping Y/N to 1/0 in column: IsWatchListMerchant
#   Mapping Y/N to 1/0 in column: IsHighRiskMCC
#   Mapping Y/N to 1/0 in column: IsBlacklistCardNo
#   Mapping Y/N to 1/0 in column: IsValidCard
#   Mapping Y/N to 1/0 in column: Is3DSecure
#   Mapping Y/N to 1/0 in column: IsWhiteListMerchant
#   Mapping Y/N to 1/0 in column: IsBDIEmail
#   Mapping Y/N to 1/0 in column: IsWhiteListCardNo
#   Mapping Y/N to 1/0 in column: IsWhitelistCardNoOpen
#   Mapping Y/N to 1/0 in column: IsWatchlistCardNo
#   Mapping Y/N to 1/0 in column: IsBlackListTID
#   Mapping Y/N to 1/0 in column: IsFirstTrx3DS
#   Mapping Y/N to 1/0 in column: IsHighRiskCountryThresholdAmt
#   Mapping Y/N to 1/0 in column: IsHighRiskCurrency
#   Mapping Y/N to 1/0 in column: IsHighRiskCurrencyThresholdAmt
#   Mapping Y/N to 1/0 in column: IsWhitelistCardNoPrevilage
#   Mapping Y/N to 1/0 in column: IsWhiteListTID
#   Mapping Y/N to 1/0 in column: IsWatchListTID
#   Mapping Y/N to 1/0 in column: IsBucket1WatchListCardNo
#   Mapping Y/N to 1/0 in column: IsBucket1BlacklistCardNo
#   Mapping Y/N to 1/0 in column: IsBucket1WhiteListCardNo
#   Mapping Y/N to 1/0 in column: IsBucket2WhiteListMerchant
#   Mapping Y/N to 1/0 in column: IsBucket2WatchListMerchant
#   Mapping Y/N to 1/0 in column: IsBucket2BlacklistMerchant
#   Applying log10 transform to column: Avg_Amt_L15M
#   Log10 transformed column: Avg_Amt_L15M
#   Applying log10 transform to column: Avg_Amt_L1H
#   Log10 transformed column: Avg_Amt_L1H
#   Applying log10 transform to column: Avg_Amt_L1D
#   Log10 transformed column: Avg_Amt_L1D
#   Applying log10 transform to column: Avg_Amt_L7D
#   Log10 transformed column: Avg_Amt_L7D
#   Applying log10 transform to column: Avg_Amt_L14D
#   Log10 transformed column: Avg_Amt_L14D
#   Applying log10 transform to column: Avg_Amt_L30D
#   Log10 transformed column: Avg_Amt_L30D
#   Applying log10 transform to column: Avg_Amt_L90D
#   Log10 transformed column: Avg_Amt_L90D
#   Applying log10 transform to column: Max_Amt_L15M
#   Log10 transformed column: Max_Amt_L15M
#   Applying log10 transform to column: Max_Amt_L1H
#   Log10 transformed column: Max_Amt_L1H
#   Applying log10 transform to column: Max_Amt_L1D
#   Log10 transformed column: Max_Amt_L1D
#   Applying log10 transform to column: Max_Amt_L7D
#   Log10 transformed column: Max_Amt_L7D
#   Applying log10 transform to column: Max_Amt_L14D
#   Log10 transformed column: Max_Amt_L14D
#   Applying log10 transform to column: Max_Amt_L30D
#   Log10 transformed column: Max_Amt_L30D
#   Applying log10 transform to column: Max_Amt_L90D
#   Log10 transformed column: Max_Amt_L90D
#   Applying log10 transform to column: Sum_Amt_L14D
#   Log10 transformed column: Sum_Amt_L14D
#   Applying log10 transform to column: Sum_Amt_L30D
#   Log10 transformed column: Sum_Amt_L30D
#   Applying log10 transform to column: Sum_Amt_L90D
#   Log10 transformed column: Sum_Amt_L90D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L15M
#   Log10 transformed column: Avg_Amt_to_MCC_L15M
#   Applying log10 transform to column: Avg_Amt_to_MCC_L1H
#   Log10 transformed column: Avg_Amt_to_MCC_L1H
#   Applying log10 transform to column: Avg_Amt_to_MCC_L1D
#   Log10 transformed column: Avg_Amt_to_MCC_L1D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L7D
#   Log10 transformed column: Avg_Amt_to_MCC_L7D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L14D
#   Log10 transformed column: Avg_Amt_to_MCC_L14D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L30D
#   Log10 transformed column: Avg_Amt_to_MCC_L30D
#   Applying log10 transform to column: Avg_Amt_to_MCC_L90D
#   Log10 transformed column: Avg_Amt_to_MCC_L90D
#   Applying log10 transform to column: Max_Amt_to_MCC_L15M
#   Log10 transformed column: Max_Amt_to_MCC_L15M
#   Applying log10 transform to column: Max_Amt_to_MCC_L1H
#   Log10 transformed column: Max_Amt_to_MCC_L1H
#   Applying log10 transform to column: Max_Amt_to_MCC_L1D
#   Log10 transformed column: Max_Amt_to_MCC_L1D
#   Applying log10 transform to column: Max_Amt_to_MCC_L7D
#   Log10 transformed column: Max_Amt_to_MCC_L7D
#   Applying log10 transform to column: Max_Amt_to_MCC_L14D
#   Log10 transformed column: Max_Amt_to_MCC_L14D
#   Applying log10 transform to column: Max_Amt_to_MCC_L30D
#   Log10 transformed column: Max_Amt_to_MCC_L30D
#   Applying log10 transform to column: Max_Amt_to_MCC_L90D
#   Log10 transformed column: Max_Amt_to_MCC_L90D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L15M
#   Log10 transformed column: Sum_Amt_to_MCC_L15M
#   Applying log10 transform to column: Sum_Amt_to_MCC_L1H
#   Log10 transformed column: Sum_Amt_to_MCC_L1H
#   Applying log10 transform to column: Sum_Amt_to_MCC_L1D
#   Log10 transformed column: Sum_Amt_to_MCC_L1D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L7D
#   Log10 transformed column: Sum_Amt_to_MCC_L7D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L14D
#   Log10 transformed column: Sum_Amt_to_MCC_L14D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L30D
#   Log10 transformed column: Sum_Amt_to_MCC_L30D
#   Applying log10 transform to column: Sum_Amt_to_MCC_L90D
#   Log10 transformed column: Sum_Amt_to_MCC_L90D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Avg_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Avg_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Max_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Max_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Max_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Max_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L15M
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L15M
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L1H
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L1H
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L1D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L1D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L7D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L7D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L14D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L14D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L30D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L30D
#   Applying log10 transform to column: Sum_Amt_to_MCC_cat_L90D
#   Log10 transformed column: Sum_Amt_to_MCC_cat_L90D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L15M
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L1H
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L1D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L7D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L14D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L30D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_cat_L90D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L15M
#   Log10 transformed column: Avg_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L1H
#   Log10 transformed column: Avg_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L1D
#   Log10 transformed column: Avg_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L7D
#   Log10 transformed column: Avg_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L14D
#   Log10 transformed column: Avg_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L30D
#   Log10 transformed column: Avg_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Avg_Amt_to_countryCode_L90D
#   Log10 transformed column: Avg_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L15M
#   Log10 transformed column: Max_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Max_Amt_to_countryCode_L1H
#   Log10 transformed column: Max_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Max_Amt_to_countryCode_L1D
#   Log10 transformed column: Max_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L7D
#   Log10 transformed column: Max_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L14D
#   Log10 transformed column: Max_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L30D
#   Log10 transformed column: Max_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Max_Amt_to_countryCode_L90D
#   Log10 transformed column: Max_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L15M
#   Log10 transformed column: Sum_Amt_to_countryCode_L15M
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L1H
#   Log10 transformed column: Sum_Amt_to_countryCode_L1H
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L1D
#   Log10 transformed column: Sum_Amt_to_countryCode_L1D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L7D
#   Log10 transformed column: Sum_Amt_to_countryCode_L7D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L14D
#   Log10 transformed column: Sum_Amt_to_countryCode_L14D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L30D
#   Log10 transformed column: Sum_Amt_to_countryCode_L30D
#   Applying log10 transform to column: Sum_Amt_to_countryCode_L90D
#   Log10 transformed column: Sum_Amt_to_countryCode_L90D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Avg_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Avg_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Max_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Max_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L15M
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L15M
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L1H
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L1H
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L1D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L1D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L7D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L7D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L14D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L14D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L30D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L30D
#   Applying log10 transform to column: Sum_Amt_to_cardAcceptor_country_L90D
#   Log10 transformed column: Sum_Amt_to_cardAcceptor_country_L90D
#   Applying log10 transform to column: Transaction Amount
#   Log10 transformed column: Transaction Amount
#   Applying log10 transform to column: TotalTrxAmountL1D
#   Log10 transformed column: TotalTrxAmountL1D
#   Applying log10 transform to column: TotalTrxAmountL7D
#   Log10 transformed column: TotalTrxAmountL7D
#   Applying log10 transform to column: TotalTrxAmount15Mi
#   Log10 transformed column: TotalTrxAmount15Mi
#   Applying log10 transform to column: CreditLimit
#   Log10 transformed column: CreditLimit
#   Applying log10 transform to column: CashCreditLimit
#   Log10 transformed column: CashCreditLimit
#   Applying log10 transform to column: TotalTrxAmount10Mi
#   Log10 transformed column: TotalTrxAmount10Mi
#   Applying log10 transform to column: TotalTrxAmountL5min
#   Log10 transformed column: TotalTrxAmountL5min
#   Applying log10 transform to column: TotalTrxAmountContactless
#   Log10 transformed column: TotalTrxAmountContactless
#   Applying log10 transform to column: IsHighRiskCountryThresholdAmt
#   Log10 transformed column: IsHighRiskCountryThresholdAmt
#   Applying log10 transform to column: IsHighRiskCurrencyThresholdAmt
#   Log10 transformed column: IsHighRiskCurrencyThresholdAmt
#   Applying log10 transform to column: TotalTrxAmount30Mi
#   Log10 transformed column: TotalTrxAmount30Mi
# Core numeric and boolean preprocessing complete.
# Transforming data using CategoryManager...
#   Transformed column 'MCC Category' to numerical codes.
#   Transformed column 'Country Code' to numerical codes.
#   Transformed column 'Cat Card Acceptor Name' to numerical codes.
#   Transformed column 'Currency Code' to numerical codes.
#   Transformed column 'AccountStatus' to numerical codes.
#   Transformed column 'CardStatus' to numerical codes.
#   Transformed column 'CardProduct' to numerical codes.
#   Transformed column 'CustomerSex' to numerical codes.
#   Transformed column 'Currency' to numerical codes.
#   Transformed column 'POSMode' to numerical codes.
#   Transformed column 'PINEntryCapability' to numerical codes.
#   Transformed column 'TransactionType' to numerical codes.
#   Transformed column 'SourceChannel' to numerical codes.
#   Transformed column 'VCardDataInputCapability' to numerical codes.
#   Transformed column 'CustomerNationality' to numerical codes.
# CategoryManager transformation complete.
# Identified numerical columns for imputation: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_ ...
# Identified categorical columns (encoded): ['MCC Category', 'Country Code', 'Cat Card Acceptor Name', 'Currency Code', 'AccountStatus', 'CardStatus', 'CardProduct', 'CustomerSex', 'Currency', 'POSMode', 'PINEntryCapability', 'TransactionType', 'SourceChannel', 'VCardDataInputCapability', 'CustomerNationality']
# Transforming data using NumericalImputer...
#   Imputed column 'time_diff' with value: 233.25
#   Imputed column 'TxnCount_L15M' with value: 0.0
#   Imputed column 'TxnCount_L1H' with value: 0.0
#   Imputed column 'TxnCount_L1D' with value: 1.0
#   Imputed column 'TxnCount_L7D' with value: 7.0
#   Imputed column 'TxnCount_L14D' with value: 13.0
#   Imputed column 'TxnCount_L30D' with value: 23.0
#   Imputed column 'TxnCount_L90D' with value: 43.0
#   Imputed column 'TxnCount_to_MCC_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_L1D' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_L7D' with value: 2.0
#   Imputed column 'TxnCount_to_MCC_L14D' with value: 3.0
#   Imputed column 'TxnCount_to_MCC_L30D' with value: 4.0
#   Imputed column 'TxnCount_to_MCC_L90D' with value: 8.0
#   Imputed column 'TxnCount_to_MCC_details_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_details_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_details_L1D' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_details_L7D' with value: 2.0
#   Imputed column 'TxnCount_to_MCC_details_L14D' with value: 3.0
#   Imputed column 'TxnCount_to_MCC_details_L30D' with value: 5.0
#   Imputed column 'TxnCount_to_MCC_details_L90D' with value: 8.0
#   Imputed column 'TxnCount_to_MCC_catcode_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_catcode_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_catcode_L1D' with value: 1.0
#   Imputed column 'TxnCount_to_MCC_catcode_L7D' with value: 4.0
#   Imputed column 'TxnCount_to_MCC_catcode_L14D' with value: 6.0
#   Imputed column 'TxnCount_to_MCC_catcode_L30D' with value: 11.0
#   Imputed column 'TxnCount_to_MCC_catcode_L90D' with value: 19.0
#   Imputed column 'TxnCount_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_MCC_cat_L1D' with value: 1.0
#   Imputed column 'TxnCount_to_MCC_cat_L7D' with value: 3.0
#   Imputed column 'TxnCount_to_MCC_cat_L14D' with value: 5.0
#   Imputed column 'TxnCount_to_MCC_cat_L30D' with value: 8.0
#   Imputed column 'TxnCount_to_MCC_cat_L90D' with value: 14.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L1D' with value: 1.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L7D' with value: 3.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L14D' with value: 5.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L30D' with value: 9.0
#   Imputed column 'TxnCount_to_cardAcceptor_cat_L90D' with value: 16.0
#   Imputed column 'TxnCount_to_countryCode_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_countryCode_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_countryCode_L1D' with value: 1.0
#   Imputed column 'TxnCount_to_countryCode_L7D' with value: 6.0
#   Imputed column 'TxnCount_to_countryCode_L14D' with value: 10.0
#   Imputed column 'TxnCount_to_countryCode_L30D' with value: 18.0
#   Imputed column 'TxnCount_to_countryCode_L90D' with value: 33.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L1D' with value: 1.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L7D' with value: 5.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L14D' with value: 8.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L30D' with value: 13.0
#   Imputed column 'TxnCount_to_cardAcceptor_country_L90D' with value: 23.0
#   Imputed column 'Avg_Amt_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_L1D' with value: 4.778158664703369
#   Imputed column 'Avg_Amt_L7D' with value: 5.2834062576293945
#   Imputed column 'Avg_Amt_L14D' with value: 5.378139972686768
#   Imputed column 'Avg_Amt_L30D' with value: 5.471024513244629
#   Imputed column 'Avg_Amt_L90D' with value: 5.551766872406006
#   Imputed column 'Max_Amt_L15M' with value: 0.0
#   Imputed column 'Max_Amt_L1H' with value: 0.0
#   Imputed column 'Max_Amt_L1D' with value: 4.95231294631958
#   Imputed column 'Max_Amt_L7D' with value: 5.708972930908203
#   Imputed column 'Max_Amt_L14D' with value: 5.931661605834961
#   Imputed column 'Max_Amt_L30D' with value: 6.175801753997803
#   Imputed column 'Max_Amt_L90D' with value: 6.365113735198975
#   Imputed column 'Sum_Amt_L14D' with value: 6.514176368713379
#   Imputed column 'Sum_Amt_L30D' with value: 6.83538293838501
#   Imputed column 'Sum_Amt_L90D' with value: 7.178675174713135
#   Imputed column 'Avg_Amt_to_MCC_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_L1D' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_L7D' with value: 4.673951148986816
#   Imputed column 'Avg_Amt_to_MCC_L14D' with value: 4.821440696716309
#   Imputed column 'Avg_Amt_to_MCC_L30D' with value: 4.953762054443359
#   Imputed column 'Avg_Amt_to_MCC_L90D' with value: 5.061819553375244
#   Imputed column 'Max_Amt_to_MCC_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_L1D' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_L7D' with value: 4.926347732543945
#   Imputed column 'Max_Amt_to_MCC_L14D' with value: 5.120449066162109
#   Imputed column 'Max_Amt_to_MCC_L30D' with value: 5.309632301330566
#   Imputed column 'Max_Amt_to_MCC_L90D' with value: 5.492720127105713
#   Imputed column 'Sum_Amt_to_MCC_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L1D' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_L7D' with value: 5.2986249923706055
#   Imputed column 'Sum_Amt_to_MCC_L14D' with value: 5.608038902282715
#   Imputed column 'Sum_Amt_to_MCC_L30D' with value: 5.928460121154785
#   Imputed column 'Sum_Amt_to_MCC_L90D' with value: 6.2379150390625
#   Imputed column 'Avg_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Avg_Amt_to_MCC_cat_L7D' with value: 4.848049163818359
#   Imputed column 'Avg_Amt_to_MCC_cat_L14D' with value: 4.971617698669434
#   Imputed column 'Avg_Amt_to_MCC_cat_L30D' with value: 5.092095375061035
#   Imputed column 'Avg_Amt_to_MCC_cat_L90D' with value: 5.185332775115967
#   Imputed column 'Max_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Max_Amt_to_MCC_cat_L7D' with value: 5.112273216247559
#   Imputed column 'Max_Amt_to_MCC_cat_L14D' with value: 5.306427001953125
#   Imputed column 'Max_Amt_to_MCC_cat_L30D' with value: 5.52058219909668
#   Imputed column 'Max_Amt_to_MCC_cat_L90D' with value: 5.698970794677734
#   Imputed column 'Sum_Amt_to_MCC_cat_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L1D' with value: 0.0
#   Imputed column 'Sum_Amt_to_MCC_cat_L7D' with value: 5.518186092376709
#   Imputed column 'Sum_Amt_to_MCC_cat_L14D' with value: 5.818617820739746
#   Imputed column 'Sum_Amt_to_MCC_cat_L30D' with value: 6.131781578063965
#   Imputed column 'Sum_Amt_to_MCC_cat_L90D' with value: 6.451018810272217
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L1D' with value: 4.0000433921813965
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L7D' with value: 4.916314125061035
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L14D' with value: 5.021943092346191
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L30D' with value: 5.158873081207275
#   Imputed column 'Avg_Amt_to_cardAcceptor_cat_L90D' with value: 5.266674995422363
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L1D' with value: 4.0414323806762695
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L7D' with value: 5.218512058258057
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L14D' with value: 5.387633800506592
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L30D' with value: 5.572087287902832
#   Imputed column 'Max_Amt_to_cardAcceptor_cat_L90D' with value: 5.755875587463379
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L1D' with value: 4.176120281219482
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L7D' with value: 5.681061267852783
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L14D' with value: 5.966826915740967
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L30D' with value: 6.277665138244629
#   Imputed column 'Sum_Amt_to_cardAcceptor_cat_L90D' with value: 6.608013153076172
#   Imputed column 'Avg_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_countryCode_L1D' with value: 4.702223777770996
#   Imputed column 'Avg_Amt_to_countryCode_L7D' with value: 5.222719192504883
#   Imputed column 'Avg_Amt_to_countryCode_L14D' with value: 5.312819480895996
#   Imputed column 'Avg_Amt_to_countryCode_L30D' with value: 5.408265113830566
#   Imputed column 'Avg_Amt_to_countryCode_L90D' with value: 5.485235691070557
#   Imputed column 'Max_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_countryCode_L1D' with value: 4.866883754730225
#   Imputed column 'Max_Amt_to_countryCode_L7D' with value: 5.636889934539795
#   Imputed column 'Max_Amt_to_countryCode_L14D' with value: 5.829562664031982
#   Imputed column 'Max_Amt_to_countryCode_L30D' with value: 6.052155494689941
#   Imputed column 'Max_Amt_to_countryCode_L90D' with value: 6.278753757476807
#   Imputed column 'Sum_Amt_to_countryCode_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_countryCode_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_countryCode_L1D' with value: 5.063224792480469
#   Imputed column 'Sum_Amt_to_countryCode_L7D' with value: 6.122707366943359
#   Imputed column 'Sum_Amt_to_countryCode_L14D' with value: 6.41076135635376
#   Imputed column 'Sum_Amt_to_countryCode_L30D' with value: 6.720290184020996
#   Imputed column 'Sum_Amt_to_countryCode_L90D' with value: 7.05148458480835
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L1D' with value: 4.414989948272705
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L7D' with value: 5.053033351898193
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L14D' with value: 5.156097888946533
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L30D' with value: 5.2614946365356445
#   Imputed column 'Avg_Amt_to_cardAcceptor_country_L90D' with value: 5.338566780090332
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L1D' with value: 4.544092655181885
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L7D' with value: 5.444808006286621
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L14D' with value: 5.6275434494018555
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L30D' with value: 5.838478088378906
#   Imputed column 'Max_Amt_to_cardAcceptor_country_L90D' with value: 6.032883167266846
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L15M' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L1H' with value: 0.0
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L1D' with value: 4.731596946716309
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L7D' with value: 5.920513153076172
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L14D' with value: 6.20412015914917
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L30D' with value: 6.5125885009765625
#   Imputed column 'Sum_Amt_to_cardAcceptor_country_L90D' with value: 6.836496353149414
#   Imputed column 'CntUnique_MCC_by_CardNo_L15M' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L1H' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L1D' with value: 1.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L7D' with value: 3.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L14D' with value: 4.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L30D' with value: 5.0
#   Imputed column 'CntUnique_MCC_by_CardNo_L90D' with value: 7.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L15M' with value: 3.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L1H' with value: 10.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L1D' with value: 89.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L7D' with value: 361.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L14D' with value: 532.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L30D' with value: 743.0
#   Imputed column 'CntUnique_CardNo_by_MCC_L90D' with value: 1065.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L15M' with value: 7.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L1H' with value: 25.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L1D' with value: 216.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L7D' with value: 681.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L14D' with value: 996.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L30D' with value: 1397.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_cat_L90D' with value: 1871.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L15M' with value: 38.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L1H' with value: 134.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L1D' with value: 928.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L7D' with value: 2291.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L14D' with value: 2857.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L30D' with value: 3396.0
#   Imputed column 'CntUnique_CardNo_by_currencyCode_L90D' with value: 3949.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L15M' with value: 19.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L1H' with value: 65.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L1D' with value: 492.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L7D' with value: 1280.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L14D' with value: 1707.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L30D' with value: 2129.0
#   Imputed column 'CntUnique_CardNo_by_cardAcceptor_country_L90D' with value: 2618.0
#   Imputed column 'Transaction Amount' with value: 5.159870624542236
#   Imputed column 'CustomerAge' with value: 41.0
#   Imputed column 'AgeOfOpenAcctTxn' with value: 2629.0
#   Imputed column 'AgeOfActiveCardTxn' with value: 1126.0
#   Imputed column 'TotalTrxAmountL1D' with value: 5.503425598144531
#   Imputed column 'TotalTrxAmountL7D' with value: 6.190331935882568
#   Imputed column 'TotalTrxAmount15Mi' with value: 5.1020941734313965
#   Imputed column 'IsBlacklistCust' with value: 0.0
#   Imputed column 'NumOfTrxL1D' with value: 2.0
#   Imputed column 'NumOfTrxL7D' with value: 8.0
#   Imputed column 'IsHighRiskCountry' with value: 0.0
#   Imputed column 'IsBlacklistMerchant' with value: 0.0
#   Imputed column 'IsWatchListMerchant' with value: 0.0
#   Imputed column 'IsHighRiskMCC' with value: 0.0
#   Imputed column 'CreditLimit' with value: 7.6901960372924805
#   Imputed column 'CashCreditLimit' with value: 7.292255878448486
#   Imputed column 'IsBlacklistCardNo' with value: 0.0
#   Imputed column 'IsValidCard' with value: 1.0
#   Imputed column 'Is3DSecure' with value: 0.0
#   Imputed column 'IsWhiteListMerchant' with value: 0.0
#   Imputed column 'IsBDIEmail' with value: 0.0
#   Imputed column 'IsWhiteListCardNo' with value: 0.0
#   Imputed column 'TotalTrxAmount10Mi' with value: 5.086719036102295
#   Imputed column 'TotalTrxAmountL5min' with value: 5.073721885681152
#   Imputed column 'TotalTrxAmountContactless' with value: 0.0
#   Imputed column 'IsWhitelistCardNoOpen' with value: 0.0
#   Imputed column 'IsWatchlistCardNo' with value: 0.0
#   Imputed column 'IsBlackListTID' with value: 0.0
#   Imputed column 'IsFirstTrx3DS' with value: 0.0
#   Imputed column 'IsHighRiskCountryThresholdAmt' with value: 0.0
#   Imputed column 'IsHighRiskCurrency' with value: 0.0
#   Imputed column 'IsHighRiskCurrencyThresholdAmt' with value: 0.0
#   Imputed column 'IsWhitelistCardNoPrevilage' with value: 0.0
#   Imputed column 'IsWhiteListTID' with value: 0.0
#   Imputed column 'IsWatchListTID' with value: 0.0
#   Imputed column 'TotalTrxAmount30Mi' with value: 4.8998260498046875
#   Imputed column 'IsBucket1WatchListCardNo' with value: 0.0
#   Imputed column 'IsBucket1BlacklistCardNo' with value: 0.0
#   Imputed column 'IsBucket1WhiteListCardNo' with value: 0.0
#   Imputed column 'IsBucket2WhiteListMerchant' with value: 0.0
#   Imputed column 'IsBucket2WatchListMerchant' with value: 0.0
#   Imputed column 'IsBucket2BlacklistMerchant' with value: 0.0
# NumericalImputer transformation complete.
# Final feature columns: ['time_diff', 'TxnCount_L15M', 'TxnCount_L1H', 'TxnCount_L1D', 'TxnCount_L7D', 'TxnCount_L14D', 'TxnCount_L30D', 'TxnCount_L90D', 'TxnCount_to_MCC_L15M', 'TxnCount_to_MCC_L1H', 'TxnCount_to_MCC_L1D', 'TxnCount_to_MCC_L7D', 'TxnCount_to_MCC_L14D', 'TxnCount_to_MCC_L30D', 'TxnCount_to_MCC_L90D', 'TxnCount_to_MCC_details_L15M', 'TxnCount_to_MCC_details_L1H', 'TxnCount_to_MCC_details_L1D', 'TxnCount_to_MCC_details_L7D', 'TxnCount_to_MCC_details_L14D', 'TxnCount_to_MCC_details_L30D', 'TxnCount_to_MCC_details_L90D', 'TxnCount_to_MCC_catcode_L15M', 'TxnCount_to_MCC_catcode_L1H', 'TxnCount_to_MCC_catcode_L1D', 'TxnCount_to_MCC_catcode_L7D', 'TxnCount_to_MCC_catcode_L14D', 'TxnCount_to_MCC_catcode_L30D', 'TxnCount_to_MCC_catcode_L90D', 'TxnCount_to_MCC_cat_L15M', 'TxnCount_to_MCC_cat_L1H', 'TxnCount_to_MCC_cat_L1D', 'TxnCount_to_MCC_cat_L7D', 'TxnCount_to_MCC_cat_L14D', 'TxnCount_to_MCC_cat_L30D', 'TxnCount_to_MCC_cat_L90D', 'TxnCount_to_cardAcceptor_cat_L15M', 'TxnCount_to_cardAcceptor_cat_L1H', 'TxnCount_to_cardAcceptor_cat_L1D', 'TxnCount_to_cardAcceptor_cat_L7D', 'TxnCount_to_cardAcceptor_cat_L14D', 'TxnCount_to_cardAcceptor_cat_L30D', 'TxnCount_to_cardAcceptor_cat_L90D', 'TxnCount_to_countryCode_L15M', 'TxnCount_to_countryCode_L1H', 'TxnCount_to_countryCode_L1D', 'TxnCount_to_countryCode_L7D', 'TxnCount_to_countryCode_L14D', 'TxnCount_to_countryCode_L30D', 'TxnCount_to_countryCode_L90D', 'TxnCount_to_cardAcceptor_country_L15M', 'TxnCount_to_cardAcceptor_country_L1H', 'TxnCount_to_cardAcceptor_country_L1D', 'TxnCount_to_cardAcceptor_country_L7D', 'TxnCount_to_cardAcceptor_country_L14D', 'TxnCount_to_cardAcceptor_country_L30D', 'TxnCount_to_cardAcceptor_country_L90D', 'Avg_Amt_L15M', 'Avg_Amt_L1H', 'Avg_Amt_L1D', 'Avg_Amt_L7D', 'Avg_Amt_L14D', 'Avg_Amt_L30D', 'Avg_Amt_L90D', 'Max_Amt_L15M', 'Max_Amt_L1H', 'Max_Amt_L1D', 'Max_Amt_L7D', 'Max_Amt_L14D', 'Max_Amt_L30D', 'Max_Amt_L90D', 'Sum_Amt_L14D', 'Sum_Amt_L30D', 'Sum_Amt_L90D', 'Avg_Amt_to_MCC_L15M', 'Avg_Amt_to_MCC_L1H', 'Avg_Amt_to_MCC_L1D', 'Avg_Amt_to_MCC_L7D', 'Avg_Amt_to_MCC_L14D', 'Avg_Amt_to_MCC_L30D', 'Avg_Amt_to_MCC_L90D', 'Max_Amt_to_MCC_L15M', 'Max_Amt_to_MCC_L1H', 'Max_Amt_to_MCC_L1D', 'Max_Amt_to_MCC_L7D', 'Max_Amt_to_MCC_L14D', 'Max_Amt_to_MCC_L30D', 'Max_Amt_to_MCC_L90D', 'Sum_Amt_to_MCC_L15M', 'Sum_Amt_to_MCC_L1H', 'Sum_Amt_to_MCC_L1D', 'Sum_Amt_to_MCC_L7D', 'Sum_Amt_to_MCC_L14D', 'Sum_Amt_to_MCC_L30D', 'Sum_Amt_to_MCC_L90D', 'Avg_Amt_to_MCC_cat_L15M', 'Avg_Amt_to_MCC_cat_L1H', 'Avg_Amt_to_MCC_cat_L1D', 'Avg_Amt_to_MCC_cat_L7D', 'Avg_Amt_to_MCC_cat_L14D', 'Avg_Amt_to_MCC_cat_L30D', 'Avg_Amt_to_MCC_cat_L90D', 'Max_Amt_to_MCC_cat_L15M', 'Max_Amt_to_MCC_cat_L1H', 'Max_Amt_to_MCC_cat_L1D', 'Max_Amt_to_MCC_cat_L7D', 'Max_Amt_to_MCC_cat_L14D', 'Max_Amt_to_MCC_cat_L30D', 'Max_Amt_to_MCC_cat_L90D', 'Sum_Amt_to_MCC_cat_L15M', 'Sum_Amt_to_MCC_cat_L1H', 'Sum_Amt_to_MCC_cat_L1D', 'Sum_Amt_to_MCC_cat_L7D', 'Sum_Amt_to_MCC_cat_L14D', 'Sum_Amt_to_MCC_cat_L30D', 'Sum_Amt_to_MCC_cat_L90D', 'Avg_Amt_to_cardAcceptor_cat_L15M', 'Avg_Amt_to_cardAcceptor_cat_L1H', 'Avg_Amt_to_cardAcceptor_cat_L1D', 'Avg_Amt_to_cardAcceptor_cat_L7D', 'Avg_Amt_to_cardAcceptor_cat_L14D', 'Avg_Amt_to_cardAcceptor_cat_L30D', 'Avg_Amt_to_cardAcceptor_cat_L90D', 'Max_Amt_to_cardAcceptor_cat_L15M', 'Max_Amt_to_cardAcceptor_cat_L1H', 'Max_Amt_to_cardAcceptor_cat_L1D', 'Max_Amt_to_cardAcceptor_cat_L7D', 'Max_Amt_to_cardAcceptor_cat_L14D', 'Max_Amt_to_cardAcceptor_cat_L30D', 'Max_Amt_to_cardAcceptor_cat_L90D', 'Sum_Amt_to_cardAcceptor_cat_L15M', 'Sum_Amt_to_cardAcceptor_cat_L1H', 'Sum_Amt_to_cardAcceptor_cat_L1D', 'Sum_Amt_to_cardAcceptor_cat_L7D', 'Sum_Amt_to_cardAcceptor_cat_L14D', 'Sum_Amt_to_cardAcceptor_cat_L30D', 'Sum_Amt_to_cardAcceptor_cat_L90D', 'Avg_Amt_to_countryCode_L15M', 'Avg_Amt_to_countryCode_L1H', 'Avg_Amt_to_countryCode_L1D', 'Avg_Amt_to_countryCode_L7D', 'Avg_Amt_to_countryCode_L14D', 'Avg_Amt_to_countryCode_L30D', 'Avg_Amt_to_countryCode_L90D', 'Max_Amt_to_countryCode_L15 ...
# Data preparation complete.

# %%
# Evaluate ALL trx
oos_results = pipeline.evaluate(X_oos, y_oos)
# Out:
# Evaluating model...
# Accuracy: 0.9955
# AUC: 0.9753
# PR AUC: 0.6788
# Precision: 0.7580
# Recall: 0.5710
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00    200054
#         True       0.76      0.57      0.65      1492
#
#     accuracy                           1.00    201546
#    macro avg       0.88      0.78      0.82    201546
# weighted avg       1.00      1.00      1.00    201546

# %%
y_oos_prob = pipeline.pipeline.predict_proba(X_oos)[:, 1]
plot_confusion_matrix(y_oos, y_oos_prob, 0.5)
# Out:
# Recall/True Positive Rate: The model got 57.1% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 75.8% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.14% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# ## Calibrated Eval

# %%
y_oos_prob_cal = calibrated_xgb.predict_proba(X_oos)[:, 1]
plot_confusion_matrix(y_oos, y_oos_prob_cal, 0.1)
# Out:
# Recall/True Positive Rate: The model got 57.64% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 75.17% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.14% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# ## Threshold Tuning

# %%
plot_confusion_matrix(y_true=y_oos, y_prob=y_oos_prob, threshold=0.02)
# Out:
# Recall/True Positive Rate: The model got 69.03% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 59.43% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.35% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
plot_confusion_matrix(y_oos, y_oos_prob_cal, 0.1)
# Out:
# Recall/True Positive Rate: The model got 57.64% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 75.17% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.14% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
len(X_oos.columns)
# Out:
# 271

# %%
import pickle

filepath = "model/credit/base_xgb_271_feats_20250619.pkl"
with open(filepath, "wb") as f:
    pickle.dump(base_xgb, f)

# %% [markdown]
# # Eval ALERT Transactions Only

# %%
# Evaluate ALERT trx only
X_oos_new, y_oos_new = pipeline.prepare_data(
    # df=df_splits["df_test"],
    df=df_oos_new,
    target_column=target_col,
    exclude_columns=["Transaction Datetime"],
    is_training=False,  # set to False for back-testing/predicting OOS data
)

# %%
# Evaluate ALERT trx only
oos_results = pipeline.evaluate(X_oos_new, y_oos_new)

# %%
y_oos_new_prob = pipeline.pipeline.predict_proba(X_oos_new)[:, 1]
plot_confusion_matrix(y_oos_new, y_oos_new_prob, 0.5)

# %% [markdown]
# # Feature Importance

# %%
# Feature importance
importance_df = pipeline.get_feature_importance(X_train_ros, y_train_ros)
# Out:
# Getting feature importances...
#   Using native feature importances.

# %%
pd.set_option("display.max_rows", None)
importance_df["importance"] = np.round(importance_df["importance"], 6)
importance_df
# Out:
#                                               feature  importance
# 11                                          time_diff    0.101744
# 32  MCC Category_BUSINESS/PROFESSIONAL/MISCELLANEO...    0.098616
# 47                                          POSMode_1    0.083393
# 17                                 Transaction Amount    0.069505
# 14                                 TotalTrxAmount30Mi    0.045291
# 10                       TxnCount_to_countryCode_L30D    0.039626
# 7                                 Sum_Amt_to_MCC_L30D    0.036443
# 4                                 Max_Amt_to_MCC_L30D    0.033320
# 1                                 Avg_Amt_to_MCC_L30D    0.032923
# 13                                 TotalTrxAmount15Mi    0.032613
# 2                                        Max_Amt_L15M    0.031431
# 12                                 TotalTrxAmount10Mi    0.030977
# 16                                TotalTrxAmountL5min    0.028444
# 0                                        Avg_Amt_L15M    0.024990
# 19                     ratio_sum_amt_to_mcc_L30D_L15M    0.024817
# 21                            RatioTrxAmountL1DL15min    0.024091
# 9                                       TxnCount_L30D    0.022904
# 49                                          POSMode_5    0.018467
# 15                                  TotalTrxAmountL1D    0.018266
# 23                            RatioTrxAmountL1DL30min    0.016225
# 22                            RatioTrxAmountL1DL10min    0.015645
# 18                     ratio_max_amt_to_mcc_L30D_L15M    0.015566
# 20                             RatioTrxAmountL1DL5min    0.015324
# 6                                 Sum_Amt_to_MCC_L15M    0.013965
# 8                         Sum_Amt_to_countryCode_L15M    0.013809
# 54                                POSMode___missing__    0.012916
# 45  MCC Category_TRAVEL/TRANSPORTATION/GAS AND FUE...    0.012753
# 3                                 Max_Amt_to_MCC_L15M    0.012134
# 5                         Max_Amt_to_countryCode_L15M    0.010739
# 46                           MCC Category___missing__    0.006108
# 43                                 MCC Category_OTHER    0.006016
# 27                             CardStatus___missing__    0.005442
# 62                     CardProductGrouped___MISSING__    0.005372
# 30                            CustomerSex___missing__    0.004858
# 38                    MCC Category_FINANCIAL SERVICES    0.003358
# 59                  CardProductGrouped_CARD_PRODUCT_6    0.002949
# 24                                       CardStatus_2    0.002841
# 61              CardProductGrouped_CARD_PRODUCT_OTHER    0.002722
# 58                  CardProductGrouped_CARD_PRODUCT_5    0.002448
# 40  MCC Category_GROCERY STORES/PHARMACIES/FOOD SE...    0.002366
# 64                              CurrencyCodeGroup_360    0.002296
# 34  MCC Category_CLOTHING/SHOES/ACCESSORIES/UNIFOR...    0.001835
# 28                                      CustomerSex_1    0.001351
# 68                              CurrencyCodeGroup_840    0.001236
# 50                                          POSMode_6    0.001222
# 51                                          POSMode_7    0.001148
# 39  MCC Category_FURNISHINGS/APPLIANCES/MAINTENANC...    0.001083
# 31            MCC Category_ASSOCIATIONS/ORGANIZATIONS    0.001065
# 55                  CardProductGrouped_CARD_PRODUCT_2    0.001011
# 53                                         POSMode_A     0.000809
# 36     MCC Category_ELECTRONIC AND TECHNICAL SERVICES    0.000756
# 70                           CurrencyCodeGroup_OTHERS    0.000749
# 65                              CurrencyCodeGroup_392    0.000614
# 42     MCC Category_LODGING — HOTELS, MOTELS, RESORTS    0.000604
# 60                  CardProductGrouped_CARD_PRODUCT_7    0.000504
# 57                  CardProductGrouped_CARD_PRODUCT_4    0.000476
# 56                  CardProductGrouped_CARD_PRODUCT_3    0.000427
# 48                                          POSMode_2    0.000406
# 35                  MCC Category_EDUCATIONAL SERVICES    0.000235
# 37   MCC Category_ENTERTAINMENT/THEATER/DANCE STUDIOS    0.000225
# 52                                          POSMode_9    0.000184
# 25                                       CardStatus_4    0.000107
# 44                     MCC Category_PERSONAL SERVICES    0.000066
# 66                              CurrencyCodeGroup_702    0.000054
# 69                              CurrencyCodeGroup_978    0.000053
# 29                                      CustomerSex_2    0.000044
# 41             MCC Category_HEALTHCARE/CHILD SERVICES    0.000020
# 33                   MCC Category_CAR RENTAL AGENCIES    0.000001
# 67                              CurrencyCodeGroup_764    0.000000
# 26                                       CardStatus_8    0.000000
# 63                     CardProductGrouped___missing__    0.000000
# 71                      CurrencyCodeGroup___missing__    0.000000

# %% [markdown]
# # Train High-Precision Model

# %%
threshold = 0.5
mask = y_prob_cal < threshold

# %%
mask_series = pd.Series(mask, index=X_test.index)
X_candidates = X_test.loc[mask_series]
y_candidates = y_test.loc[mask_series]

# %%
X_test.shape, X_candidates.shape
# Out:
# ((359185, 72), (350952, 72))

# %%
# split data
X_cdd_train, X_cdd_test, y_cdd_train, y_cdd_test = pipeline.split_data(
    X_candidates, y_candidates, test_size=0.2
)
# Out:
# Splitting data into train and test sets...
# Data splitting complete.

# %%
# OverSampling
ros_sampler = ImbalancedSampler(
    algorithm="RandomOverSampler",
    sampler_type="upsample",
    target_ratio=0.2,  # 7%
    random_state=1234,
)

X_cdd_train_ros, y_cdd_train_ros = ros_sampler.fit_resample(X_cdd_train, y_cdd_train)
# Out:
# Original dataset shape: Counter({False: 280358, True: 403})
# Resampled dataset shape using RandomOverSampler: Counter({False: 280358, True: 56071})

# %%
# re-init
pipeline = ModelPipeline(model_type="xgboost", random_state=42)
# built and train
pipeline.build_pipeline()
pipeline.train(X_cdd_train_ros, y_cdd_train_ros, show_training_log=False)
# Out:
# Initializing ModelPipeline with model type: xgboost
# Retrieving model instance for type: xgboost
# Building pipeline...
# Pipeline built.
# Training model...
# C:\Users\Administrator\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [19:17:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Model training complete.

# %%
xgb = pipeline.get_model()
# Out:
# Returning trained model...

# %%
calibrated_xgb = CalibratedClassifierCV(estimator=xgb, method="sigmoid", cv="prefit")
calibrated_xgb.fit(X_cdd_train_ros, y_cdd_train_ros)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=XGBClassifier(base_score=None, booster=None,
#                                                callbacks=None,
#                                                colsample_bylevel=None,
#                                                colsample_bynode=None,
#                                                colsample_bytree=None,
#                                                device=None,
#                                                early_stopping_rounds=None,
#                                                enable_categorical=False,
#                                                eval_metric='logloss',
#                                                feature_types=None,
#                                                feature_weights=None, gamma=None,
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=None, max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=None, max_leaves=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=1000, n_jobs=-1,
#                                                num_parallel_tree=None, ...))

# %%
# Evaluate
cdd_test_results = pipeline.evaluate(X_cdd_test, y_cdd_test)
# Out:
# Evaluating model...
# Accuracy: 0.9980
# AUC: 0.8419
# PR AUC: 0.0868
# Precision: 0.2029
# Recall: 0.1386
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     70090
#         True       0.20      0.14      0.16       101
#
#     accuracy                           1.00     70191
#    macro avg       0.60      0.57      0.58     70191
# weighted avg       1.00      1.00      1.00     70191

# %% [markdown]
# ## Backtest with OOS Data

# %%
threshold_oos = 0.5
mask_oos = y_oos_prob_cal < threshold_oos

# %%
mask_oos_series = pd.Series(mask_oos, index=X_oos.index)
X_oos_cdd = X_oos.loc[mask_oos_series]
y_oos_cdd = y_oos.loc[mask_oos_series]

# %%
y_oos_cdd_prob = xgb.predict_proba(X_oos_cdd)[:, 1]

# %%
plot_confusion_matrix(y_oos_cdd, y_oos_cdd_prob, 0.5)
# Out:
# Recall/True Positive Rate: The model got 2.19% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 6.8% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 0.07% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
y_oos_cdd_prob_cal = calibrated_xgb.predict_proba(X_oos_cdd)[:, 1]

# %%
plot_confusion_matrix(y_oos_cdd, y_oos_cdd_prob_cal, 0.5)
# Out:
# Recall/True Positive Rate: The model got 44.48% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 63.62% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 1.51% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %%
y_oos_cdd_rf_cal = calibrated_rf.predict_proba(X_oos_cdd)[:, 1]

# %%
plot_confusion_matrix(y_oos_cdd, y_oos_cdd_rf_cal, 0.6)
# Out:
# Recall/True Positive Rate: The model got 70.05% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 28.81% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 10.28% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# ## Combine Proba

# %%
y_oos_rf = calibrated_rf.predict_proba(X_oos)[:, 1]
y_oos_xgb = calibrated_xgb.predict_proba(X_oos)[:, 1]

# %%
rf_prop = 0.1
xgb_prop = 0.9

y_oos_combine = (y_oos_rf * rf_prop) + (y_oos_xgb * xgb_prop)
plot_confusion_matrix(y_oos, y_oos_combine, 0.0015)
# Out:
# Recall/True Positive Rate: The model got 86.46% of correctly predicted fraud from all of the actual fraud transactions
# Precision: The model got 12.01% of correctly predicted fraud from all transactions that predicted as fraud
# False Positive Rate: The model got 4.72% of incorrectly predicted a fraud transactions when the actual transactions is non-fraud

# %% [markdown]
# ## Analysis

# %%
df_analysis_post_rf_base = X_oos_cdd.copy()
df_analysis_post_rf_base["Confirmed"] = y_oos_cdd
df_analysis_post_rf_base["RF_cal_proba"] = calibrated_rf.predict_proba(X_oos_cdd)[:, 1]
df_analysis_post_rf_base = df_analysis_post_rf_base[["Confirmed", "RF_cal_proba"]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df_analysis_post_rf_base,
    x="RF_cal_proba",
    hue="Confirmed",
    common_norm=False,
    fill=True,
    palette="Set1",
    alpha=0.5,
)
# Out:
# <Axes: xlabel='RF_cal_proba', ylabel='Density'>
